# %%
import os
import pandas as pd

# %%
import fiftyone as fo
import fiftyone.zoo as foz

classes = [
    "refrigerator",
]

dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="train",
    label_types=["detections"],
    classes=classes,
    max_samples=2000,
)
# Out:
# ...
# Found annotations at 'C:\Users\saini\fiftyone\coco-2017\raw\instances_train2017.json'
# Found annotations at 'C:\Users\saini\fiftyone\coco-2017\raw\instances_train2017.json'
# 1524 images found; downloading the remaining 476
#  100% |██████████████████| 476/476 [2.4m elapsed, 0s remaining, 0.3 images/s]
# Writing annotations for 7636 downloaded samples to 'C:\Users\saini\fiftyone\coco-2017\train\labels.json'
# Dataset info written to 'C:\Users\saini\fiftyone\coco-2017\info.json'
# Loading 'coco-2017' split 'train'
#  100% |███████████████| 2000/2000 [10.4s elapsed, 0s remaining, 188.3 samples/s]
# Dataset 'coco-2017-train-2000' created

# %%
dataset.export(
    export_dir="E:/dsai_group4_project/datasets/coco_refrigerator",
    dataset_type=fo.types.YOLOv5Dataset,
)
# Out:
#  100% |███████████████| 2000/2000 [18.2s elapsed, 0s remaining, 74.4 samples/s]

# %%
print(dataset.name)
# Out:
# coco-2017-train-2000

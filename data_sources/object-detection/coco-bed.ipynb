# %%
import os
import pandas as pd
import fiftyone as fo
import fiftyone.zoo as foz

# %%
import fiftyone as fo
import fiftyone.zoo as foz

classes = [
    "bed",
]

dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="train",
    label_types=["detections"],
    classes=classes,
    max_samples=1000,
)
# Out:
# Downloading split 'train' to 'C:\Users\saini\fiftyone\coco-2017\train' if necessary
# Downloading annotations to 'C:\Users\saini\fiftyone\coco-2017\tmp-download\annotations_trainval2017.zip'
# Downloading annotations to 'C:\Users\saini\fiftyone\coco-2017\tmp-download\annotations_trainval2017.zip'
#   42% |██\---|  805.0Mb/1.9Gb [7.7m elapsed, 10.2m remaining, 2.0Mb/s]

# %%
dataset.export(
    export_dir="E:/dsai_group4_project/datasets/coco_bed",
    dataset_type=fo.types.YOLOv5Dataset,
)
# Out:
#    0% ||--------------|    0/2000 [9.4ms elapsed, ? remaining, ? samples/s]
#  100% |███████████████| 2000/2000 [7.9s elapsed, 0s remaining, 258.3 samples/s]

# %%
print(dataset.name)
# Out:
# coco-2017-train-2000

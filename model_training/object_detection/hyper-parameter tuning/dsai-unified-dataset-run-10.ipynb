# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.5 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 143.8MB/s 0.1s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="final_combo",
)

# %%
param_grid = [
    {"imgsz": 768, "batch": 32, "scale": 0.5, "mosaic": 1.0, "mixup": 0.2},
    {"imgsz": 832, "batch": 32, "scale": 0.5, "mosaic": 1.0, "mixup": 0.2},
    {"imgsz": 832, "batch": 48, "scale": 0.5, "mosaic": 1.0, "mixup": 0.2},
    {"imgsz": 768, "batch": 32, "scale": 0.7, "mosaic": 1.0, "mixup": 0.3},
    {"imgsz": 832, "batch": 32, "scale": 0.7, "mosaic": 1.0, "mixup": 0.3},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.33 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=832, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.3, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=final_combo, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/final_combo/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.7, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 62.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 3.5±2.2 ms, read: 16.8±9.5 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 119.5it/s 25.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.6 ms, read: 16.6±6.0 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 134.6it/s 17.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/final_combo/run_1/labels.jpg...
# Image sizes 832 train, 832 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/final_combo/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      13.4G       1.56      2.755      1.563        314        832: 100% ━━━━━━━━━━━━ 94/94 1.1s/it 1:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.4s/it 50.9s
#                    all       2340      10428      0.444       0.35      0.343      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      13.4G      1.586      1.981      1.617        226        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.7s
#                    all       2340      10428      0.471      0.314      0.282      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      14.3G       1.63      2.041       1.66        275        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.316      0.228      0.186      0.087
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      13.5G      1.683      2.157      1.727        302        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.8s
#                    all       2340      10428      0.339       0.31      0.257      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      13.5G      1.655      2.071      1.692        290        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.4s
#                    all       2340      10428      0.437       0.32      0.316      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      13.4G      1.632      2.054       1.69        255        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428      0.403      0.308      0.298      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      13.5G      1.599      1.977      1.662        235        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428      0.462      0.371      0.355      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      13.4G      1.584      1.956      1.659        269        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.3s
#                    all       2340      10428      0.455      0.376      0.359      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      13.4G      1.552      1.923      1.637        254        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428      0.432      0.401      0.377      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      13.4G      1.555      1.884      1.629        265        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.437       0.39      0.364      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      13.5G      1.531      1.861      1.618        212        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428      0.457      0.391      0.361      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      13.4G      1.512      1.812      1.593        281        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428      0.508      0.408      0.408      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      13.5G      1.507      1.799      1.599        458        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.2s
#                    all       2340      10428      0.513      0.422       0.41       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      13.5G      1.502      1.773      1.578        263        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428      0.492      0.431      0.416      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      13.4G      1.475      1.739      1.568        220        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.502      0.436      0.423       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      13.5G      1.464      1.733      1.561        253        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.476      0.451      0.423      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      13.1G      1.463      1.692      1.547        300        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.506      0.435      0.436      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      13.5G      1.451      1.668      1.545        344        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428       0.59      0.434       0.45      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      13.4G      1.448      1.674      1.545        261        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428      0.535      0.476      0.463      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      13.5G      1.442      1.635      1.537        354        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.534      0.472      0.469      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      13.6G      1.415      1.597      1.519        290        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.2s
#                    all       2340      10428      0.516      0.495      0.481      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      13.4G      1.418      1.627      1.523        388        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428       0.56      0.439      0.468      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      13.4G       1.42      1.587      1.517        282        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428      0.569      0.481      0.481      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      13.4G      1.397      1.585      1.501        275        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.3s
#                    all       2340      10428      0.509      0.472      0.459      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      13.5G      1.389      1.548      1.487        221        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.2s
#                    all       2340      10428      0.549      0.478      0.483      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      13.5G      1.398      1.553      1.496        300        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.2s
#                    all       2340      10428      0.531      0.487       0.48      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      13.4G      1.396      1.538      1.497        266        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.552       0.48      0.485      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      13.6G      1.365      1.506      1.481        313        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.557      0.494      0.504      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      13.5G      1.358      1.484      1.468        264        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.8s
#                    all       2340      10428      0.566      0.496      0.504      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      13.5G      1.358      1.477      1.471        261        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428        0.6      0.481      0.512      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      13.5G       1.35       1.46      1.459        380        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.9s
#                    all       2340      10428      0.565      0.499      0.504      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      13.5G      1.341      1.444      1.454        258        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.0s
#                    all       2340      10428      0.589      0.506       0.52      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      13.2G      1.327      1.424      1.449        225        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.6s
#                    all       2340      10428      0.604      0.508      0.534      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      13.5G      1.337      1.413      1.448        325        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.576      0.506      0.519      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      13.5G      1.313      1.391      1.429        238        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.6s
#                    all       2340      10428      0.586      0.501      0.514      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      13.6G      1.311      1.386      1.431        346        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.585      0.499      0.512      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      13.6G      1.309      1.367      1.423        236        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428       0.59      0.501      0.525      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      13.5G      1.305      1.369      1.423        228        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.588      0.497      0.511      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      13.5G       1.31      1.359      1.425        243        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.601      0.491       0.52      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      13.1G      1.299      1.331      1.409        388        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.611      0.507      0.536       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      13.5G      1.289      1.333      1.416        254        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.629      0.528      0.552      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      13.5G      1.284      1.309      1.408        250        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.595      0.523       0.54       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      13.4G      1.272      1.312      1.403        265        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.606      0.527      0.541      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      13.4G      1.263      1.279      1.396        299        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.614      0.524      0.544      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      13.4G      1.267      1.275      1.392        243        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.599      0.521      0.541      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      13.5G      1.231      1.243      1.371        255        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.607      0.524      0.545      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      13.4G      1.234      1.238      1.371        227        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.626      0.514      0.552      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      13.3G      1.227       1.23      1.367        278        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.4s
#                    all       2340      10428      0.638      0.516      0.555      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      13.4G      1.229      1.217      1.367        324        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.617      0.536      0.554      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      13.4G      1.207      1.196      1.349        201        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.612      0.537      0.555      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80        13G      1.218      1.192      1.355        327        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.638      0.537      0.567      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      13.5G      1.213      1.186      1.353        312        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.642      0.526       0.56      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      13.2G      1.212      1.179      1.351        265        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428       0.63      0.541      0.563      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      13.5G      1.191      1.165      1.336        212        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.628      0.522      0.554      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      13.4G      1.201      1.156       1.34        278        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.6s
#                    all       2340      10428       0.64      0.529      0.558      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      13.5G      1.192      1.133      1.332        235        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.636      0.532      0.556      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      13.5G      1.173       1.12      1.322        269        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.627      0.535      0.563      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      13.5G      1.179      1.116      1.324        419        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.649      0.529      0.567      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      13.4G      1.162      1.091      1.308        226        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.8s
#                    all       2340      10428      0.631      0.538      0.567      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      13.4G      1.161      1.088      1.315        282        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.664      0.513       0.56      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      13.6G      1.145      1.073      1.301        399        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.619      0.535      0.561      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      13.4G      1.151      1.078      1.298        290        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.629       0.54      0.566      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      13.5G      1.153      1.071      1.299        374        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.8s
#                    all       2340      10428      0.625      0.545      0.571       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      13.5G      1.139      1.046      1.294        249        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.632      0.536      0.565      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      13.5G      1.123      1.041      1.286        232        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.625      0.547      0.568       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      13.5G      1.133      1.061      1.298        301        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.644      0.537      0.573      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      13.5G      1.134      1.054      1.298        225        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428       0.65      0.529      0.572      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      13.6G      1.136      1.038      1.292        322        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428       0.66      0.535      0.573      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      13.6G      1.117       1.02      1.278        330        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.677      0.524      0.569       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      13.4G      1.117      1.014      1.284        283        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.663      0.536      0.573      0.375
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      13.4G     0.9842      0.798      1.199        113        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.637      0.526      0.545      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      13.5G     0.9406     0.7073      1.171         85        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.633      0.533      0.552      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      13.5G     0.9497     0.6979      1.176        115        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.656      0.524      0.552      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      13.5G     0.9285     0.6813      1.164        134        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.641       0.54      0.553       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      13.5G     0.9245     0.6664      1.166        116        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.4s
#                    all       2340      10428       0.66      0.527      0.557      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      13.5G     0.9291     0.6732      1.165         86        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428       0.63      0.548      0.558      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      13.5G     0.9257      0.667      1.165         96        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.637      0.549      0.558      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      13.5G     0.9246     0.6666      1.169         83        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.648      0.542       0.56      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      13.5G     0.9211     0.6641      1.158         87        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.652      0.537      0.559      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      13.5G     0.9215     0.6616      1.162         94        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.5s
#                    all       2340      10428      0.643      0.541       0.56      0.365
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 70, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 80 epochs completed in 2.436 hours.
# Optimizer stripped from /kaggle/working/runs/detect/final_combo/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/final_combo/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/final_combo/run_1/weights/best.pt...
# Ultralytics 8.4.33 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 24.7s
#                    all       2340      10428      0.665      0.537      0.572      0.374
#                 person        989       3681      0.766      0.637      0.715      0.461
#                  table        678        970      0.685      0.565       0.63      0.429
#           potted plant        460       1204      0.706      0.659      0.687      0.367
#                  chair        531       1363      0.697      0.455      0.523      0.346
#                   sofa        449        596      0.716      0.706      0.735       0.54
#                   lamp        253        441      0.607      0.535      0.528      0.332
#                   door        171        249      0.561      0.446      0.451      0.268
#                cabinet        104        797      0.678      0.225      0.308      0.163
#               wardrobe         91        102      0.488       0.49      0.409      0.301
#           refrigerator        539        683      0.624      0.517      0.547      0.365
#                    bed        290        342      0.782      0.673      0.763      0.545
# Speed: 0.2ms preprocess, 5.9ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/final_combo/run_1

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  imgsz  batch  scale  mosaic  mixup     map50  map50_95  precision  \
# 0    1    832     32    0.7     1.0    0.3  0.572369  0.374224   0.664617
#
#      recall
# 0  0.537025

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.0 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 140.3MB/s 0.1s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="weight_decay",
)

# %%
param_grid = [
    {"weight_decay": 0.0005},
    {"weight_decay": 0.001},
    {"weight_decay": 0.0001},
    {"weight_decay": 0.00005},
    {"weight_decay": 0.0005, "optimizer": "AdamW"},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=weight_decay, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/weight_decay/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 62.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 3.6±3.3 ms, read: 12.1±4.2 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 166.7it/s 18.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 16.6±4.7 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 173.6it/s 13.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/weight_decay/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/weight_decay/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.89G      1.532       2.57      1.517        297        640: 100% ━━━━━━━━━━━━ 94/94 1.4it/s 1:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.3s/it 46.4s
#                    all       2340      10428      0.452       0.31      0.298      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.76G       1.55      1.924      1.556        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.355      0.303      0.277      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.76G      1.617      2.011      1.612        287        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.7s
#                    all       2340      10428      0.281      0.243      0.185     0.0823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.72G      1.652      2.084      1.655        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.368      0.287      0.252      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.67G      1.612      2.002      1.615        367        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.438      0.337      0.307      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.75G      1.606      2.011      1.634        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428       0.51      0.288      0.285      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.84G      1.573      1.939      1.605        205        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.482      0.338      0.324      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.84G      1.537      1.881      1.581        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.399      0.364       0.34       0.19
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.69G      1.519      1.841      1.573        308        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428       0.45      0.363       0.36      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.77G      1.523      1.829      1.562        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.428      0.386      0.359      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.76G      1.505      1.778      1.554        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.467      0.368      0.372      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.71G      1.489       1.76      1.547        251        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.496      0.348      0.358      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.65G      1.474      1.743      1.542        291        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.525      0.419      0.417      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.68G       1.47      1.712      1.524        260        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.529       0.42      0.427      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.76G      1.458      1.693      1.517        289        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428       0.49      0.413      0.404      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.09G      1.441      1.675      1.508        322        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428       0.54      0.431      0.436      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.77G      1.439      1.645      1.504        247        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.523      0.389      0.401      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.72G      1.426      1.625        1.5        234        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.494      0.437      0.418      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.76G      1.399      1.589      1.472        236        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.515      0.453      0.445      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      7.75G      1.416       1.58      1.471        217        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.518       0.42      0.437      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.64G      1.393      1.535      1.461        274        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.528      0.444      0.445      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      7.78G      1.397      1.567      1.471        293        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.532      0.413      0.427      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.96G       1.38      1.526      1.467        227        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.538      0.438      0.439       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      7.99G      1.373      1.509      1.456        293        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.539      0.464      0.468      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      8.06G      1.363      1.482      1.439        239        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.527      0.447      0.442      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      8.07G      1.353      1.462      1.438        284        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.565      0.469      0.479      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.63G      1.351      1.476      1.438        232        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.554      0.475       0.48      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      8.01G      1.331      1.448      1.424        228        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.588      0.463        0.5      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      8.04G      1.326      1.418      1.418        268        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428       0.55      0.459      0.477      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.69G      1.334      1.419      1.417        247        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.586      0.495      0.514      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80       7.9G      1.316        1.4      1.406        192        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.553      0.454      0.476      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.78G      1.303      1.379      1.401        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.589      0.469      0.483        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      8.04G      1.303      1.368      1.394        200        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.568      0.467      0.482      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.72G      1.292      1.353      1.386        283        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.561      0.461      0.481      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.97G       1.28      1.326      1.378        189        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.568      0.476      0.492      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      7.79G      1.274      1.312      1.379        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.629      0.458      0.497      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.94G      1.291      1.331      1.383        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.584      0.473      0.503      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.73G      1.257      1.273      1.361        222        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.608      0.467      0.493      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.95G      1.248      1.262      1.354        238        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.604      0.477      0.495      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.76G      1.255      1.257      1.353        319        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.597      0.501      0.521      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      8.04G      1.244      1.255       1.35        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428       0.62      0.492      0.527      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.77G      1.239      1.231      1.347        216        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.602      0.511      0.539      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.96G      1.232      1.239      1.346        172        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.595      0.485       0.51      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.76G      1.239      1.208      1.335        312        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.611      0.474        0.5      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.73G      1.219      1.203      1.337        145        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.611      0.471      0.505      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      8.01G      1.195      1.169       1.32        314        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428       0.61      0.492      0.534      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.99G      1.202      1.173      1.321        197        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.612      0.504       0.53      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      8.06G      1.194      1.144      1.313        225        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.604       0.53      0.548      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.99G      1.188      1.148      1.311        244        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.621      0.474      0.502      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.74G      1.177      1.133      1.301        238        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.628      0.503      0.529      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.69G      1.185      1.126      1.301        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.621      0.505      0.531      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.77G      1.179      1.133      1.304        281        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.631      0.476      0.519      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.74G      1.179      1.128      1.299        253        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.612       0.51      0.531      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.75G      1.164      1.095      1.288        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.581      0.525      0.529      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.71G      1.147      1.079      1.282        264        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.637      0.501      0.539      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      8.07G       1.15      1.076      1.283        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.625      0.483      0.517      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.72G      1.143      1.056      1.271        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.615      0.492      0.513      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.71G       1.14      1.055      1.272        219        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.637      0.506      0.537      0.345
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 48, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 58 epochs completed in 1.066 hours.
# Optimizer stripped from /kaggle/working/runs/detect/weight_decay/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/weight_decay/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/weight_decay/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.604       0.53      0.548      0.348
#                 person        989       3681      0.723       0.61      0.671      0.411
#                  table        678        970      0.634      0.572      0.607      0.404
#           potted plant        460       1204      0.641       0.67      0.645      0.335
#                  chair        531       1363      0.622      0.458      0.487       0.31
#                   sofa        449        596      0.679      0.702      0.743      0.537
#                   lamp        253        441      0.492      0.562      0.506      0.301
#                   door        171        249      0.516      0.329      0.351      0.189
#                cabinet        104        797      0.676      0.243      0.357      0.183
#               wardrobe         91        102      0.465      0.412      0.397      0.286
#           refrigerator        539        683      0.604      0.517      0.541      0.357
#                    bed        290        342      0.593      0.757      0.724      0.516
# Speed: 0.1ms preprocess, 3.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/weight_decay/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=weight_decay, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/weight_decay/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.001, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.3±1.3 ms, read: 98.3±35.0 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 476.6it/s 6.3s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 72.2±29.9 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 363.6it/s 6.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.001), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/weight_decay/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/weight_decay/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.92G       1.53      2.574      1.514        297        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 51.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.492      0.308      0.307      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.76G      1.553      1.912      1.556        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.435      0.306      0.276      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.75G      1.615      2.012      1.617        287        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.385       0.25      0.197     0.0886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.72G      1.649      2.076      1.658        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.297      0.311      0.235      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.69G      1.612       2.02      1.629        367        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.359      0.315      0.268      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.96G      1.604      2.002      1.628        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.49      0.243      0.245       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.62G      1.575       1.94      1.616        205        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.418      0.341      0.319      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      8.09G      1.539      1.877      1.588        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.452      0.383      0.352      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.94G      1.526      1.843      1.576        308        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.479      0.373       0.36      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.78G      1.524       1.84      1.575        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.447      0.363      0.349      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.78G      1.501      1.797      1.562        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.488      0.399      0.389      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.75G      1.482       1.76      1.545        251        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.7s
#                    all       2340      10428      0.491      0.416      0.404      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.64G      1.473      1.752      1.546        291        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.477      0.419      0.406      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.73G      1.476      1.722       1.53        260        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.478      0.431      0.417       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.76G      1.454      1.693      1.517        289        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.506      0.407      0.412      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.08G      1.443      1.673      1.506        322        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.514      0.401      0.407      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.78G      1.434      1.632      1.501        247        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.544       0.41       0.41      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.73G       1.43      1.633      1.503        234        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.524      0.426      0.437      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.68G      1.398      1.595      1.476        236        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.555      0.427      0.441      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      7.79G      1.406      1.575      1.473        217        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.536      0.436      0.446      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.71G      1.391      1.537      1.461        274        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.508      0.417      0.427      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      8.03G      1.401      1.556       1.47        293        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.438      0.421      0.394      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.81G      1.495       1.83      1.612        225        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.506      0.423      0.414      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.75G      1.489      1.845      1.612        244        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428       0.45      0.428      0.398      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.73G      1.489      1.827      1.608        238        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.488      0.407      0.394      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80       7.7G      1.488      1.808      1.594        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.448      0.435      0.406      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.77G      1.484      1.825      1.605        281        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.455      0.425      0.406      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.66G      1.483      1.831      1.598        253        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.483      0.448      0.414      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.74G      1.463      1.778      1.585        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.469      0.443      0.418      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.85G      1.443      1.758      1.579        264        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.472      0.459      0.426      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      8.01G      1.451      1.764      1.584        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.491      0.434      0.418      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.72G      1.442      1.734      1.572        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.491       0.44      0.434      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.69G      1.437      1.724      1.565        219        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.49      0.447      0.427       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.75G      1.434      1.718      1.568        231        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.51      0.428      0.432      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.62G      1.423      1.711      1.552        248        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.513      0.449       0.43      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.71G      1.413      1.704      1.544        286        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.49      0.453      0.431      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.02G      1.421      1.697      1.552        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.513      0.453      0.443      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.71G      1.407      1.664      1.539        229        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.524       0.45      0.443      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.72G      1.404      1.666      1.536        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.503      0.455       0.44      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.81G      1.415      1.674      1.543        290        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.536      0.443      0.448      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.69G      1.387      1.644      1.529        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.508      0.459      0.445      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.64G      1.372      1.615      1.513        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.506      0.459      0.446      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.76G      1.389      1.647      1.529        171        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.546      0.443      0.454      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.72G      1.395      1.648      1.536        302        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.517      0.462      0.454       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80       7.8G      1.382      1.645      1.527        382        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.51       0.47      0.456      0.272
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80       7.7G      1.268      1.465      1.433        114        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 50.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428        0.5      0.434      0.428      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      7.76G      1.229      1.312      1.408         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.496      0.454      0.441      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.74G      1.231      1.282      1.412        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.515      0.448      0.443      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      7.72G       1.23      1.267      1.407        134        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.509      0.452      0.447      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      7.75G      1.212      1.258      1.401        118        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.509      0.455      0.449      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      7.62G      1.218      1.244      1.397         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.516      0.455      0.453      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      7.63G      1.208      1.234      1.396         98        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.516      0.458      0.454      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      7.75G      1.214      1.247        1.4         85        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.518      0.453      0.454      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      7.76G      1.206      1.242      1.388         87        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.518      0.458      0.455      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      7.75G      1.206      1.229      1.394         95        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.523      0.456      0.454      0.273
#
# 80 epochs completed in 1.493 hours.
# Optimizer stripped from /kaggle/working/runs/detect/weight_decay/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/weight_decay/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/weight_decay/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.5s
#                    all       2340      10428      0.524      0.452      0.454      0.273
#                 person        989       3681      0.659      0.545      0.586      0.332
#                  table        678        970      0.581      0.506      0.521      0.325
#           potted plant        460       1204      0.616      0.624      0.602      0.309
#                  chair        531       1363      0.563      0.389      0.399      0.242
#                   sofa        449        596      0.635      0.663       0.68      0.459
#                   lamp        253        441       0.46      0.447      0.391      0.216
#                   door        171        249      0.401      0.209      0.262      0.153
#                cabinet        104        797      0.509      0.177       0.26      0.131
#               wardrobe         91        102      0.336      0.314      0.239      0.153
#           refrigerator        539        683      0.485      0.419      0.412      0.257
#                    bed        290        342       0.52      0.684      0.639      0.427
# Speed: 0.1ms preprocess, 3.4ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/weight_decay/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  weight_decay     map50  map50_95  precision    recall optimizer
# 0    1       0.00050  0.548048  0.348128   0.603995  0.530210       NaN
# 1    2       0.00100  0.542247  0.349242   0.638028  0.502423       NaN
# 2    3       0.00010  0.550769  0.353262   0.625230  0.533135       NaN
# 3    4       0.00005  0.551725  0.352334   0.638251  0.517412       NaN
# 4    5       0.00050  0.453787  0.272997   0.524138  0.452295     AdamW

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

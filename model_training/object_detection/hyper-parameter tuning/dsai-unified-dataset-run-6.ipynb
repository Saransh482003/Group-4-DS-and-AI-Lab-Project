# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.5 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 129.6MB/s 0.1s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="rotation_perspective",
)

# %%
param_grid = [
    {"degrees": 5, "perspective": 0.0},
    {"degrees": 10, "perspective": 0.0005},
    {"degrees": 15, "perspective": 0.001},
    {"degrees": 20, "perspective": 0.001},
    {"degrees": 10, "perspective": 0.002},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=5, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=rotation_perspective, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/rotation_perspective/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 68.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.9±0.9 ms, read: 20.8±6.6 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 225.7it/s 13.3s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 21.5±5.8 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 276.0it/s 8.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/rotation_perspective/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/rotation_perspective/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.89G       1.41      2.503      1.426        288        640: 100% ━━━━━━━━━━━━ 94/94 1.4it/s 1:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.2s/it 43.6s
#                    all       2340      10428      0.371      0.328      0.321      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.78G      1.478       1.86       1.49        196        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.359      0.289      0.252      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.76G      1.546      1.925      1.536        282        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.355      0.275       0.22      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G       1.59      2.022      1.592        255        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.353      0.275      0.246      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.72G       1.55      1.961       1.56        364        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.405      0.306      0.286      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.73G      1.552      1.961      1.577        210        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.515      0.299      0.291      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.87G      1.529      1.888      1.553        206        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.422      0.391      0.349      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.86G      1.488      1.827      1.524        182        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.446      0.365      0.347      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.72G      1.485      1.802      1.525        303        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.442      0.401      0.381      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.79G      1.481      1.795      1.518        243        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.455      0.395      0.375      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80       7.8G      1.463      1.747      1.507        207        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.512      0.382      0.389       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.74G       1.44      1.716      1.491        246        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.504      0.402        0.4      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.68G      1.436      1.712      1.493        289        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.497      0.397      0.391      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.76G      1.432       1.67      1.474        255        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.526      0.424      0.437      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.79G      1.418      1.652      1.466        282        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.517       0.45      0.457      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.12G      1.407      1.634      1.457        321        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428       0.55      0.388      0.424      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      8.05G      1.397      1.588      1.453        248        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.523      0.428      0.438      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.75G      1.384      1.579      1.446        233        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.524      0.455      0.459      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.97G       1.36      1.544      1.421        234        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.556      0.442      0.448      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80       7.8G       1.38      1.536      1.423        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.551      0.471      0.483      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.73G      1.357        1.5      1.413        272        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.539      0.466      0.473      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      7.79G      1.365      1.511      1.422        291        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.568      0.463      0.475      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.75G      1.345      1.491      1.416        228        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.549      0.446      0.458      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      8.02G      1.332      1.465      1.403        291        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.527      0.505      0.479       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      7.78G      1.315      1.439      1.382        234        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.566      0.454      0.469      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      8.12G      1.305      1.405      1.384        284        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.542      0.477      0.482      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.73G      1.305      1.425      1.383        230        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.548      0.492      0.494      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.78G      1.292        1.4      1.375        225        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.555       0.46      0.472       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      7.81G      1.279      1.367      1.362        260        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.567      0.455      0.474      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.76G      1.282      1.363      1.359        245        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.593      0.483      0.514      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      8.01G      1.272      1.357      1.354        189        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.584      0.459      0.476      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.74G      1.266       1.32      1.349        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.614      0.445      0.484      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      7.72G      1.262       1.32      1.344        197        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.593      0.459      0.494      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.75G      1.246       1.29      1.334        278        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.614      0.465      0.502      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.98G       1.23      1.271      1.325        190        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.585      0.473      0.498      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80       7.8G      1.228      1.263      1.326        219        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.593      0.492      0.511       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.66G      1.242      1.283      1.334        232        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.589      0.493       0.51      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.71G       1.21      1.219       1.31        218        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.604      0.471      0.501      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.67G      1.202      1.214      1.304        237        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.586      0.486      0.502      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.72G      1.211      1.208      1.305        312        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.576      0.481      0.507      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.75G      1.196      1.208      1.301        276        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.582      0.471      0.486      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      8.06G      1.191      1.192      1.299        217        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.602        0.5      0.522      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.66G       1.19      1.187      1.296        173        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.613      0.501      0.524      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.73G      1.189      1.155      1.283        311        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.62       0.47      0.499      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      8.01G      1.163      1.155      1.282        144        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.647       0.48      0.512       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.69G      1.153      1.125      1.272        310        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.596      0.511      0.534      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.76G      1.156      1.121      1.271        196        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.635      0.496      0.542      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.69G      1.149        1.1      1.263        222        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.633       0.49      0.523      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.71G      1.142      1.096       1.26        234        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.655      0.489      0.526      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.76G      1.128      1.076      1.252        234        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.606      0.516      0.542      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.73G      1.136      1.073      1.252        229        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.627      0.518      0.543      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.63G      1.136      1.081      1.257        278        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.637      0.484      0.517      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.78G      1.131       1.08      1.252        249        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.653       0.48      0.521      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.76G      1.116      1.042      1.238        255        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.637      0.489      0.523      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80       7.8G      1.097      1.026      1.234        259        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.629      0.506      0.534      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      7.85G      1.103      1.025      1.232        275        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.642      0.495      0.533      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.75G      1.098      1.005      1.225        280        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.647      0.503      0.539       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.77G      1.092      1.002      1.222        221        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.662      0.493      0.539      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.76G      1.082     0.9865       1.22        226        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.647      0.508      0.539      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.64G      1.081     0.9892      1.215        243        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.648      0.503      0.534      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.66G      1.064     0.9717      1.202        285        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.625      0.523      0.545      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.12G      1.077     0.9804      1.213        218        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.614      0.515       0.54      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.78G      1.061     0.9491      1.205        229        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.655      0.502       0.54      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      8.04G      1.064     0.9635      1.205        249        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.657      0.487      0.541      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.81G      1.065     0.9613      1.204        286        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.657       0.49      0.535      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.71G      1.044     0.9412      1.193        239        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.641      0.505      0.538       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80         8G      1.023     0.9123      1.179        216        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.685      0.478      0.535      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.78G      1.037     0.9341       1.19        166        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.672      0.495      0.541      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.75G      1.048      0.933      1.199        298        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.648       0.51       0.54      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.75G      1.043      0.937      1.195        379        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.649      0.499      0.536       0.35
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.72G      0.897     0.6791      1.076        114        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.648      0.483      0.521      0.334
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 61, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 71 epochs completed in 1.442 hours.
# Optimizer stripped from /kaggle/working/runs/detect/rotation_perspective/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/rotation_perspective/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/rotation_perspective/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.0s
#                    all       2340      10428      0.627      0.523      0.545      0.353
#                 person        989       3681      0.718      0.622      0.677      0.431
#                  table        678        970      0.663      0.571      0.615      0.415
#           potted plant        460       1204      0.611       0.66      0.645      0.337
#                  chair        531       1363      0.623      0.474      0.493       0.32
#                   sofa        449        596      0.699       0.73      0.748      0.544
#                   lamp        253        441      0.595      0.526      0.519      0.315
#                   door        171        249      0.557      0.242      0.306      0.186
#                cabinet        104        797      0.744      0.231      0.347       0.18
#               wardrobe         91        102      0.399      0.416      0.357      0.248
#           refrigerator        539        683      0.611      0.542      0.551      0.375
#                    bed        290        342      0.673      0.737      0.731      0.537
# Speed: 0.1ms preprocess, 4.0ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/rotation_perspective/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=rotation_perspective, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/rotation_perspective/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.7±0.6 ms, read: 224.5±103.4 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 774.4it/s 3.9s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 139.3±72.0 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 482.0it/s 4.9s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/rotation_perspective/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/rotation_perspective/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      8.01G      1.569      2.598      1.547        303        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 58.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.372      0.326      0.287      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.78G      1.592      1.954      1.589        201        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.365      0.342      0.294      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.78G      1.653      2.045      1.646        294        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.347      0.252      0.203     0.0885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.59G      1.686      2.117      1.687        258        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428       0.35      0.328      0.281      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.75G      1.659      2.072      1.664        394        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.354       0.32      0.268      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.75G      1.658      2.041      1.672        217        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.561      0.299      0.298      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.87G      1.625       1.99      1.648        209        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.429      0.344       0.32      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80       7.7G      1.601      1.935      1.628        186        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.79G      1.383       1.63      1.519        192        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.599      0.472      0.506        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80       7.7G      1.364      1.597      1.499        359        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.564        0.5      0.515       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.77G      1.372      1.595      1.493        237        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.572      0.496      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.74G       1.37      1.565      1.489        238        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428       0.56      0.492      0.507      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80       7.8G      1.364      1.563      1.489        277        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.589      0.477      0.507      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      8.11G      1.352       1.55      1.482        282        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.597      0.472      0.507      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.75G      1.355      1.546       1.48        275        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.594      0.504      0.533       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.77G      1.358      1.539      1.484        356        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.602       0.49       0.52      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80       7.8G      1.352       1.54       1.48        268        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.58      0.482      0.498      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.73G      1.348      1.497      1.465        257        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.608      0.493      0.533      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      8.05G      1.329      1.485      1.465        302        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.609      0.498      0.532      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      7.77G      1.323      1.487       1.46        287        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.599      0.494      0.519      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.88G      1.328      1.466      1.458        312        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.601      0.495      0.526       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.76G      1.325      1.469      1.453        275        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.615       0.49      0.529      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.77G      1.315      1.455      1.456        250        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.603      0.504      0.532      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.79G       1.31      1.456      1.444        265        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.633      0.488      0.527      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.83G      1.296      1.429      1.433        296        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.611      0.498      0.529      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.01G      1.318      1.449      1.445        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.633      0.508      0.547      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80       7.8G      1.302      1.427       1.44        268        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.619      0.504      0.532      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.74G      1.301      1.431       1.44        286        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.628      0.492      0.535       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.92G      1.308       1.43      1.437        330        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.617       0.51      0.546      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.71G      1.289      1.408      1.424        271        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.607      0.491      0.526      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.76G      1.265      1.389      1.408        265        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.636      0.504      0.547      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.86G      1.293      1.409       1.43        200        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.619       0.51      0.539      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.72G      1.289      1.395      1.425        309        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428       0.63      0.505      0.543      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.73G      1.284      1.385      1.423        395        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.632        0.5      0.538      0.334
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.54G       1.19      1.081      1.339        114        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.642      0.465      0.513      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      7.79G      1.155     0.9489      1.311         86        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.616      0.493      0.524      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.76G      1.148      0.925      1.308        117        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428       0.61      0.493      0.522       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      7.75G      1.148     0.9241      1.307        132        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.603      0.502      0.525      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      7.78G      1.142     0.9019      1.308        117        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.607      0.503      0.525      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      7.78G      1.139     0.9071      1.299         87        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.607      0.504      0.527      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      8.02G      1.136     0.8939      1.302         98        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.619      0.503      0.529      0.325
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 67, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 77 epochs completed in 1.570 hours.
# Optimizer stripped from /kaggle/working/runs/detect/rotation_perspective/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/rotation_perspective/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/rotation_perspective/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.3s
#                    all       2340      10428      0.638      0.503      0.548      0.337
#                 person        989       3681      0.717      0.606       0.67       0.39
#                  table        678        970      0.709      0.512      0.611      0.391
#           potted plant        460       1204      0.667      0.648      0.665      0.333
#                  chair        531       1363      0.675       0.44      0.487        0.3
#                   sofa        449        596       0.72      0.674      0.742       0.52
#                   lamp        253        441      0.589      0.542      0.523      0.305
#                   door        171        249      0.445      0.257      0.318      0.165
#                cabinet        104        797      0.722      0.232      0.368      0.187
#               wardrobe         91        102       0.47      0.402       0.35      0.236
#           refrigerator        539        683      0.623      0.524      0.554      0.371
#                    bed        290        342      0.685      0.696      0.738      0.509
# Speed: 0.1ms preprocess, 4.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/rotation_perspective/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  degrees  perspective     map50  map50_95  precision    recall
# 0    1        5       0.0000  0.544542  0.353434   0.626669  0.522851
# 1    2       10       0.0005  0.545194  0.347028   0.629858  0.512816
# 2    3       15       0.0010  0.542225  0.341189   0.644370  0.500678
# 3    4       20       0.0010  0.549503  0.342232   0.650084  0.507555
# 4    5       10       0.0020  0.547708  0.337005   0.638423  0.503089

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

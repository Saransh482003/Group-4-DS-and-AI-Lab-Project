# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.0 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 110.1MB/s 0.2s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="scale_tuning",
)

# %%
param_grid = [
    {"scale":0.3, "translate":0.10, "mosaic":1.0, "mixup":0.0},
    {"scale":0.5, "translate":0.10, "mosaic":1.0, "mixup":0.0},
    {"scale":0.7, "translate":0.10, "mosaic":1.0, "mixup":0.0},
    {"scale":0.5, "translate":0.15, "mosaic":1.0, "mixup":0.0},
    {"scale":0.5, "translate":0.20, "mosaic":1.0, "mixup":0.2},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=scale_tuning, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/scale_tuning/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.3, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 30.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 123.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.1±2.5 ms, read: 21.5±7.2 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 324.0it/s 9.3s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 27.5±12.7 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 328.9it/s 7.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/scale_tuning/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/scale_tuning/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.94G      1.415      2.508      1.442        210        640: 100% ━━━━━━━━━━━━ 94/94 1.4it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.2s/it 44.5s
#                    all       2340      10428      0.388      0.338      0.319      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.64G       1.44      1.772      1.482        208        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.419      0.316      0.298      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.58G      1.482      1.819      1.526        200        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.401      0.271      0.218      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.526      1.929      1.576        151        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.337      0.297      0.246      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.76G      1.493      1.851      1.547        193        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.372      0.347      0.293      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.58G      1.455      1.805      1.528        176        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.425      0.321      0.314       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.79G      1.439      1.757      1.505        185        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.435       0.33      0.293       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.78G      1.414      1.683      1.495        165        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.461      0.365      0.358        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.69G      1.394      1.635      1.473        163        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.461      0.334      0.333      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.72G       1.38      1.626      1.472        244        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.447      0.366      0.359      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.74G      1.356       1.58      1.449        162        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.45      0.399      0.384      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.78G      1.356      1.546      1.444        169        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.523      0.395      0.394      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.52G      1.337      1.511      1.433        220        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.505      0.424      0.424      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.73G      1.308       1.45       1.41        169        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.512      0.419      0.421      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.72G      1.308      1.448      1.415        171        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.514      0.441       0.45      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      7.73G      1.294      1.416      1.399        227        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.489      0.434      0.429      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.72G       1.29      1.382      1.393        204        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.508      0.429      0.431       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.76G      1.278      1.356      1.389        208        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.514      0.438      0.436      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.73G      1.267      1.357      1.382        154        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.534      0.418      0.432      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      7.75G       1.25      1.331      1.363        214        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.538      0.449      0.451      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.77G      1.244      1.275      1.361        209        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428       0.53      0.438      0.449      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      7.73G      1.231      1.276      1.354        253        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.569      0.407      0.426      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.78G      1.221      1.236      1.341        200        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428       0.53      0.457      0.466      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      7.46G      1.214      1.228      1.336        218        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.539      0.476      0.477      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      7.74G      1.207      1.225      1.331        208        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.564      0.427       0.44      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.58G      1.193      1.185      1.322        193        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.578      0.461      0.476      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.76G      1.172      1.185      1.313        216        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.574      0.457      0.468      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      8.01G      1.166      1.162      1.312        198        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.598      0.456      0.477      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      7.55G      1.171      1.135      1.305        189        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.588      0.461      0.482      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.77G      1.162       1.11      1.296        205        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.576      0.455      0.474      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      7.56G      1.133      1.093      1.276        202        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.557      0.464      0.479      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.51G      1.126      1.073      1.271        224        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.576      0.481      0.499      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      7.67G      1.121      1.059      1.269        160        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.561      0.491      0.495      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.64G      1.125      1.038      1.266        245        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.594      0.472      0.496      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.52G      1.108       1.02      1.257        173        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.584      0.486      0.504      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      7.72G      1.094      1.001      1.252        177        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.601      0.484      0.507      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.55G      1.087     0.9901      1.242        134        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.597      0.472      0.491      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.62G      1.074     0.9625      1.235        221        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428       0.61      0.459      0.495      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.62G       1.06     0.9491      1.231        227        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.609      0.488      0.516       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.55G      1.068     0.9441      1.228        232        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.589      0.461      0.486      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.47G      1.057     0.9287      1.221        214        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428       0.63       0.47      0.504      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.49G      1.054     0.9204      1.217        170        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.4s
#                    all       2340      10428      0.602       0.49      0.509      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.61G      1.036     0.9085      1.208        165        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.599      0.469      0.493      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.77G      1.037     0.8953      1.202        203        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.616      0.495      0.515      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.64G       1.03     0.8784      1.205        171        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.612       0.48      0.506       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.57G      1.016     0.8586      1.192        228        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.625      0.468        0.5      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80       7.6G      1.012     0.8641      1.193        213        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.606      0.461      0.489      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.75G     0.9957     0.8351      1.178        214        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428       0.62      0.473      0.503      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      8.02G     0.9891     0.8294       1.17        186        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428       0.64      0.477      0.508      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.97G     0.9793      0.808      1.173        168        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.616      0.478      0.506       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.76G     0.9733      0.802       1.17        161        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.614      0.471      0.501      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.75G     0.9649     0.7955      1.161        250        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.621      0.489      0.515      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      8.04G     0.9588     0.7739      1.157        182        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.631      0.482      0.512      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.75G      0.962     0.7852      1.151        164        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.643      0.488      0.521      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80       7.8G     0.9499     0.7512      1.142        232        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.625      0.504      0.523      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      7.78G     0.9279       0.74      1.142        167        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.644      0.473      0.513      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.72G     0.9309     0.7411       1.14        198        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.622       0.49       0.51      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.73G     0.9146     0.7182      1.125        175        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.624      0.478      0.506       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.78G     0.9135     0.7172      1.128        178        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428       0.62      0.485      0.514      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.73G     0.9098     0.7149      1.126        193        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.4s
#                    all       2340      10428      0.626      0.487      0.516      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.97G     0.9003     0.6964      1.118        272        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.624       0.49      0.514      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      7.74G     0.8931     0.6998      1.116        199        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.663      0.466      0.512      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80       7.8G      0.893     0.6864      1.118        176        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.628      0.482      0.511      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.71G     0.8786     0.6774      1.109        187        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.621      0.479      0.504       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80       7.8G     0.8831     0.6852       1.11        201        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.647      0.484      0.516      0.329
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 55, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 65 epochs completed in 1.281 hours.
# Optimizer stripped from /kaggle/working/runs/detect/scale_tuning/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/scale_tuning/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/scale_tuning/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.5s
#                    all       2340      10428      0.625      0.504      0.523      0.331
#                 person        989       3681      0.706      0.604      0.651      0.401
#                  table        678        970      0.651      0.543      0.583      0.386
#           potted plant        460       1204      0.622      0.635      0.627      0.318
#                  chair        531       1363      0.686      0.418      0.483      0.314
#                   sofa        449        596      0.696      0.685        0.7      0.506
#                   lamp        253        441       0.58      0.526       0.48      0.275
#                   door        171        249      0.525      0.297       0.34      0.198
#                cabinet        104        797      0.707      0.278      0.366      0.171
#               wardrobe         91        102      0.412      0.363      0.315      0.225
#           refrigerator        539        683      0.602      0.539      0.523      0.353
#                    bed        290        342      0.689      0.653      0.688      0.494
# Speed: 0.1ms preprocess, 3.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/scale_tuning/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=scale_tuning, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/scale_tuning/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.4 ms, read: 203.2±83.1 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 721.1it/s 4.2s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 141.3±69.5 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 462.7it/s 5.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/scale_tuning/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/scale_tuning/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80         8G      1.417      2.483      1.415        219        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.395      0.312      0.292      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80       7.7G      1.456      1.768       1.46        226        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.336      0.332      0.281      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.84G      1.491      1.802      1.497        201        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.387      0.224      0.196     0.0906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.77G      1.535      1.919      1.562        175        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.414      0.256      0.229      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.76G      1.524      1.849       1.54        207        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.42       0.34      0.297      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.57G      1.478      1.812      1.521        206        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.365      0.317       0.27      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.75G      1.451      1.719      1.483        194        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.442      0.352      0.325      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.74G      1.429      1.677      1.467        172        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.426      0.359      0.336      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.74G      1.413       1.64      1.456        177        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428       0.48      0.372      0.369      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.98G      1.396      1.633      1.459        266        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.442       0.41      0.378       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.76G      1.383      1.581      1.442        155        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.462      0.382      0.364      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.78G      1.379      1.541      1.435        187        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.544      0.376      0.402       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.77G      1.353      1.505      1.419        233        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.512      0.434      0.434      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.78G      1.336      1.471      1.403        198        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.467      0.402      0.385      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.78G      1.335      1.464      1.407        177        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.1s
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.66G      1.253      1.275      1.359        231        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.604      0.472      0.504      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.75G      1.261      1.259      1.357        312        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.621      0.498      0.531      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.77G      1.245      1.256      1.348        273        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.574       0.47      0.485      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.73G      1.246      1.243      1.355        219        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.596      0.517      0.531      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.73G      1.235      1.234      1.348        170        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.573      0.504      0.516      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.75G      1.241      1.217       1.34        306        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.616      0.501       0.53      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.63G      1.221      1.214       1.34        145        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.614      0.484      0.518      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80       7.7G      1.196      1.184      1.322        314        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.606      0.503      0.526      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.98G      1.199      1.175      1.319        194        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.613      0.502      0.532      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.84G        1.2      1.151      1.313        222        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.588      0.505       0.52      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.79G      1.189      1.144      1.308        240        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.628        0.5      0.527      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.75G      1.177      1.131      1.299        230        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.621      0.507      0.536       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.71G      1.186      1.128      1.302        231        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.608      0.507      0.534      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80       7.8G      1.185      1.139      1.303        269        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.623      0.489      0.525      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.66G      1.178      1.129      1.299        247        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.653      0.488      0.537       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.76G      1.171      1.103      1.289        246        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.616      0.511      0.543      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.92G      1.142      1.079      1.282        261        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.632      0.517      0.542      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      8.04G      1.154      1.079      1.284        277        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.659      0.499      0.534      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.83G      1.148      1.057      1.272        270        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.628      0.508      0.537      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.78G      1.142      1.057      1.273        211        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.632      0.506      0.545      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.76G      1.129      1.044      1.268        224        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.641      0.509      0.544      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      8.03G      1.127      1.045      1.262        245        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.666      0.499      0.535      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.75G      1.112       1.03      1.254        288        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.658      0.517      0.558      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.05G      1.127      1.037      1.263        217        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.657      0.495       0.54      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.79G      1.108     0.9998      1.252        230        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.651      0.501      0.539      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.99G      1.113      1.011      1.251        246        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.672      0.494      0.546      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.76G      1.115      1.011       1.25        286        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.634      0.517      0.548      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.73G      1.095     0.9902      1.243        243        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.634      0.502       0.54      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.99G      1.076     0.9666      1.228        217        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.662      0.498      0.544      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.79G      1.088     0.9805      1.238        169        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.646       0.51      0.544       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.76G        1.1     0.9877      1.247        290        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.633      0.507       0.54      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      8.01G      1.092     0.9847      1.245        382        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.626      0.518      0.545      0.351
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.54G     0.9395     0.7212      1.118        113        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.629      0.493      0.522      0.333
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 61, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 71 epochs completed in 1.409 hours.
# Optimizer stripped from /kaggle/working/runs/detect/scale_tuning/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/scale_tuning/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/scale_tuning/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.4s
#                    all       2340      10428      0.659      0.516      0.557      0.356
#                 person        989       3681      0.737        0.6      0.677      0.425
#                  table        678        970      0.722      0.541      0.623      0.419
#           potted plant        460       1204      0.676      0.639      0.645      0.337
#                  chair        531       1363      0.675      0.461      0.504      0.324
#                   sofa        449        596      0.686      0.711      0.726      0.527
#                   lamp        253        441      0.624      0.503      0.508      0.297
#                   door        171        249      0.629      0.301      0.364      0.206
#                cabinet        104        797      0.739      0.266      0.414      0.203
#               wardrobe         91        102      0.446      0.441      0.389       0.28
#           refrigerator        539        683      0.602      0.518      0.533      0.359
#                    bed        290        342      0.715      0.696       0.75      0.544
# Speed: 0.1ms preprocess, 3.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/scale_tuning/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  scale  translate  mosaic  mixup     map50  map50_95  precision  \
# 0    1    0.3       0.10     1.0    0.0  0.523066  0.330880   0.625055
# 1    2    0.5       0.10     1.0    0.0  0.536358  0.337072   0.626625
# 2    3    0.7       0.10     1.0    0.0  0.548368  0.355611   0.644126
# 3    4    0.5       0.15     1.0    0.0  0.545958  0.346450   0.635233
# 4    5    0.5       0.20     1.0    0.2  0.557476  0.356415   0.659029
#
#      recall
# 0  0.503776
# 1  0.507123
# 2  0.520351
# 3  0.516659
# 4  0.516299

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

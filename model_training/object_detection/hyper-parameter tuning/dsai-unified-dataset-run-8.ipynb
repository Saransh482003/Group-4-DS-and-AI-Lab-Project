# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.3 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 78.3MB/s 0.2s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="optimizer_lr",
)

# %%
param_grid = [
    {"optimizer": "SGD", "lr0": 0.01},
    {"optimizer": "SGD", "lr0": 0.005},
    {"optimizer": "AdamW", "lr0": 0.001},
    {"optimizer": "AdamW", "lr0": 0.0005},
    {"optimizer": "AdamW", "lr0": 0.0003},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=optimizer_lr, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/optimizer_lr/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 70.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.4±0.7 ms, read: 29.6±12.2 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 288.9it/s 10.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 33.7±11.4 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 312.2it/s 7.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/optimizer_lr/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/optimizer_lr/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.87G      1.513       2.52      1.503        297        640: 100% ━━━━━━━━━━━━ 94/94 1.4it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.2s/it 44.0s
#                    all       2340      10428      0.503       0.45      0.448      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.77G      1.429      1.634       1.43        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.488      0.447      0.426      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.74G      1.519      1.783      1.496        287        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.369      0.228      0.191     0.0814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.71G      1.666      2.077      1.634        258        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.284      0.212      0.186     0.0815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.66G      1.665      2.123      1.636        367        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.339      0.293      0.225      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.69G      1.669      2.113      1.665        215        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.521      0.282      0.265      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.82G      1.645      2.064      1.642        205        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.378      0.299      0.263      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.82G      1.599      2.006      1.627        186        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.412      0.304       0.29      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.59G      1.583      1.961      1.613        308        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.464      0.336      0.336      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.71G      1.586      1.965      1.607        249        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.452       0.33      0.327      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.75G      1.565       1.91      1.593        209        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.422      0.372      0.352      0.198
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 11 epochs completed in 0.226 hours.
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/optimizer_lr/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.0s
#                    all       2340      10428      0.502      0.451      0.448      0.265
#                 person        989       3681      0.675      0.724      0.735      0.416
#                  table        678        970      0.456      0.627      0.547      0.332
#           potted plant        460       1204      0.533       0.65      0.582      0.271
#                  chair        531       1363      0.694      0.486      0.572      0.335
#                   sofa        449        596      0.553        0.8      0.715      0.448
#                   lamp        253        441      0.337      0.329      0.243      0.147
#                   door        171        249      0.138     0.0187     0.0423     0.0195
#                cabinet        104        797      0.476     0.0125     0.0923     0.0379
#               wardrobe         91        102      0.222      0.134      0.109     0.0693
#           refrigerator        539        683      0.695        0.4      0.484      0.316
#                    bed        290        342      0.746       0.78      0.805      0.522
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/optimizer_lr/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=optimizer_lr, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/optimizer_lr/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.8±0.7 ms, read: 259.4±79.7 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 770.0it/s 3.9s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 127.7±78.6 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 487.9it/s 4.8s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: SGD(lr=0.005, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/optimizer_lr/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/optimizer_lr/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80       7.9G      1.538      2.735      1.521        297        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.633      0.431      0.442       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.92G      1.392      1.603      1.407        199        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.486      0.509      0.481      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.97G       1.42      1.583      1.416        287        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.485      0.448       0.43      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.94G      1.484      1.681      1.476        258        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.421      0.326      0.314      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.91G      1.474      1.688      1.471        367        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.48      0.386      0.384      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.69G      1.491      1.699      1.502        215        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.506      0.379      0.388      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      8.06G      1.458      1.659      1.479        205        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.494      0.419      0.407      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.82G      1.431      1.631      1.463        186        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.463      0.431      0.412      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.91G      1.422      1.607       1.46        308        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.506      0.399        0.4      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.99G      1.435      1.611      1.461        249        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.515      0.403      0.409      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.98G      1.424      1.565      1.454        209        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.516      0.451      0.442      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.98G      1.413      1.553      1.443        251        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.532      0.422      0.439      0.265
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 2, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 12 epochs completed in 0.234 hours.
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_2/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_2/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/optimizer_lr/run_2/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.3s
#                    all       2340      10428      0.488      0.508      0.481      0.281
#                 person        989       3681      0.744       0.68      0.738      0.418
#                  table        678        970      0.521      0.618      0.549      0.335
#           potted plant        460       1204      0.562      0.691       0.63        0.3
#                  chair        531       1363      0.529      0.572      0.529       0.31
#                   sofa        449        596      0.665      0.742      0.762      0.492
#                   lamp        253        441      0.303      0.472      0.297      0.163
#                   door        171        249      0.205      0.133      0.116     0.0449
#                cabinet        104        797      0.168       0.39      0.167     0.0758
#               wardrobe         91        102      0.257      0.118      0.152     0.0897
#           refrigerator        539        683      0.659      0.387      0.519      0.319
#                    bed        290        342       0.75      0.784      0.828      0.541
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/optimizer_lr/run_2
#
#
# ========== RUN 3 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_3, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=optimizer_lr, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/optimizer_lr/run_3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.8±0.7 ms, read: 196.1±75.8 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 812.1it/s 3.7s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 123.3±62.8 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 517.8it/s 4.5s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/optimizer_lr/run_3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/optimizer_lr/run_3
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.92G      1.616      2.478      1.596        297        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 55.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.5s
#                    all       2340      10428      0.508      0.126       0.12     0.0556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.82G      1.673      2.168      1.684        199        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.5s
#                    all       2340      10428      0.353       0.24      0.201     0.0921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      8.03G      1.708      2.221      1.718        287        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.317       0.19      0.151     0.0643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.98G      1.727      2.268      1.755        258        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.354      0.265      0.201     0.0952
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.72G      1.686      2.212      1.713        367        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.317      0.263       0.21      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.74G       1.68      2.192      1.716        215        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.465      0.289      0.275      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.87G      1.643        2.1      1.679        205        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.426      0.341      0.287      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.86G      1.609      2.049      1.655        186        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.451      0.333      0.317       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.63G      1.586      2.009      1.639        308        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.421       0.31      0.279      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80       7.8G      1.599      2.012      1.645        249        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.422      0.385      0.359      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80       7.8G      1.569      1.944      1.626        209        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.401      0.374      0.333      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.74G      1.545      1.915       1.61        251        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428       0.43      0.384      0.359      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.68G      1.529      1.886       1.61        291        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.443      0.386       0.37      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.77G       1.53      1.858      1.586        260        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428       0.45       0.41      0.374       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.75G      1.509      1.833      1.577        289        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.511      0.396      0.396       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.12G      1.492      1.818       1.56        322        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.489      0.426      0.405      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      8.04G      1.481      1.774      1.551        247        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.493      0.409      0.416      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.99G      1.489      1.779      1.557        234        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.489      0.419      0.416      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.78G      1.453      1.732       1.53        236        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.494      0.408       0.41      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      7.83G      1.457      1.712      1.526        217        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.512      0.448      0.444       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.68G      1.446      1.667      1.513        274        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.8s
#                    all       2340      10428      0.514      0.434      0.434      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      7.82G      1.455      1.697      1.527        293        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.499      0.431       0.42      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.75G      1.432      1.651      1.518        227        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.536      0.415      0.423       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      7.77G       1.42      1.628      1.505        293        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.518      0.458      0.453      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      7.84G      1.408      1.611      1.491        239        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.549      0.405      0.427      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.84G      1.392      1.575      1.484        284        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.516      0.471      0.459      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.76G      1.399      1.587      1.487        232        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.529      0.465       0.46       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.78G      1.386      1.569      1.479        228        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428       0.54      0.474      0.477      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      7.81G      1.372      1.537      1.465        268        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.514      0.464      0.461       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.79G      1.373      1.527      1.456        247        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.546      0.464      0.466      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      7.79G      1.364      1.527      1.453        192        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.573      0.435      0.458      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      8.05G      1.352      1.499      1.445        215        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.533       0.44      0.433      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      7.82G      1.352      1.486      1.441        200        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.541      0.459      0.466      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.76G      1.338       1.47      1.433        283        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.563      0.459      0.476      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80         8G      1.326      1.446      1.424        189        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.558       0.45      0.468      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      8.09G      1.326      1.432      1.422        220        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.575      0.479      0.497      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.73G       1.34       1.45      1.437        237        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.573      0.483      0.492      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.605      0.474      0.505      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.65G      1.249      1.249      1.342        284        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.574      0.476      0.497      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.76G      1.259       1.27      1.343        232        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.569      0.501      0.519      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.71G      1.244      1.253       1.34        228        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.594      0.497      0.513       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      7.84G      1.235       1.23       1.33        268        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.7s
#                    all       2340      10428      0.558       0.49      0.505      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.74G      1.242      1.216      1.327        247        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.594      0.487      0.504      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      7.79G      1.232      1.216      1.326        192        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.586      0.471      0.488      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80       7.8G      1.225      1.192      1.317        215        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.637      0.467      0.506      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      8.06G      1.216      1.185      1.314        200        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.582      0.486      0.503       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.84G      1.203      1.159      1.301        283        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428       0.61      0.513      0.532      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.84G      1.194      1.149      1.299        189        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.606      0.507      0.518      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      7.81G       1.19      1.132      1.298        220        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428        0.6      0.526      0.537      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.66G       1.21      1.148      1.305        237        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.623      0.491      0.522      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.99G      1.175      1.104      1.283        222        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.606      0.502      0.516      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.98G      1.164        1.1      1.277        238        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.618      0.504      0.511      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80       7.8G      1.174      1.091      1.274        319        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.649      0.512      0.552      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      8.08G       1.16      1.084      1.271        279        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.631      0.503      0.528      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.74G       1.16      1.074      1.274        216        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.622      0.505      0.522      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.76G      1.153       1.07      1.271        172        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.621      0.517      0.531      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      8.03G       1.16      1.062      1.264        312        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.632        0.5      0.531      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.78G      1.135      1.045      1.259        145        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.614      0.503      0.517      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.79G      1.117      1.025      1.251        314        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.622      0.513       0.54      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.71G      1.124      1.016      1.245        197        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.648      0.507      0.543      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.82G       1.12      0.996      1.241        225        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428       0.63      0.529      0.547      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.77G       1.11      1.002      1.237        244        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.657      0.498      0.537      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.77G      1.101     0.9852      1.228        238        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.635       0.51      0.533      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.72G      1.107     0.9811      1.231        237        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.655      0.493      0.537      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.81G      1.113     0.9981      1.238        281        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.644      0.503      0.533      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.78G      1.108      0.993      1.231        253        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.638      0.509      0.537       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.79G      1.094     0.9563       1.22        258        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.632      0.511      0.537      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.75G      1.077     0.9475      1.216        264        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.645      0.509      0.537      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      8.05G      1.081     0.9433      1.219        279        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.632      0.505      0.538      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.83G      1.073     0.9255      1.208        279        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428       0.62      0.516      0.534      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.73G      1.072     0.9294      1.209        219        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 52.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.644      0.511      0.538      0.348
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 48, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 58 epochs completed in 1.129 hours.
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/optimizer_lr/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/optimizer_lr/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.8s
#                    all       2340      10428      0.633      0.529      0.547      0.354
#                 person        989       3681      0.732      0.628      0.687      0.442
#                  table        678        970      0.657      0.565      0.612      0.409
#           potted plant        460       1204      0.658      0.647      0.649      0.341
#                  chair        531       1363      0.677      0.448      0.495       0.32
#                   sofa        449        596      0.639       0.73      0.729      0.532
#                   lamp        253        441      0.589      0.528      0.518      0.298
#                   door        171        249      0.493      0.345      0.337      0.203
#                cabinet        104        797      0.809      0.218      0.326      0.171
#               wardrobe         91        102      0.413      0.471      0.374      0.269
#           refrigerator        539        683      0.598       0.52      0.538      0.368
#                    bed        290        342      0.695      0.713      0.755      0.549
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/optimizer_lr/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run optimizer     lr0     map50  map50_95  precision    recall
# 0    1       SGD  0.0100  0.447919  0.264968   0.502157  0.450949
# 1    2       SGD  0.0050  0.480547  0.280707   0.487512  0.507617
# 2    3     AdamW  0.0010  0.547668  0.349072   0.631935  0.517655
# 3    4     AdamW  0.0005  0.545114  0.344123   0.634761  0.498526
# 4    5     AdamW  0.0003  0.547281  0.354474   0.632640  0.528549

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

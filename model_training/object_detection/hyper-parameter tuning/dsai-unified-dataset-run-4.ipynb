# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.2 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 143.2MB/s 0.1s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="batch_size",
)

# %%
param_grid = [
    {"batch": 16},
    {"batch": 32},
    {"batch": 48},
    {"batch": 64},
    {"batch": 32, "imgsz": 832},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.33 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=832, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=batch_size, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/batch_size/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 73.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.0±1.1 ms, read: 31.5±10.8 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 241.2it/s 12.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 27.5±8.7 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 248.5it/s 9.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/batch_size/run_1/labels.jpg...
# Image sizes 832 train, 832 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/batch_size/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      13.5G      1.534      2.774      1.598        296        832: 100% ━━━━━━━━━━━━ 94/94 1.1s/it 1:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.3s/it 47.1s
#                    all       2340      10428       0.42      0.352       0.34      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      13.4G      1.544      1.946      1.625        199        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.469      0.318        0.3      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      13.5G      1.602      2.026      1.674        288        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.7s
#                    all       2340      10428       0.31      0.298      0.247      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      13.6G      1.633      2.094      1.726        258        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.456      0.262       0.24      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      13.5G      1.585      2.037      1.684        368        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.6s
#                    all       2340      10428      0.393      0.343      0.313      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      13.5G      1.589      2.006      1.699        215        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 23.1s
#                    all       2340      10428      0.604      0.275      0.265      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      13.6G      1.554      1.943      1.667        205        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.419      0.336      0.315      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      13.6G       1.51      1.883      1.642        186        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.456      0.395      0.385      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      13.5G      1.494      1.839      1.626        308        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.459      0.365      0.349      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      13.5G      1.496      1.825      1.619        249        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.432      0.407      0.378      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      13.5G      1.479      1.796      1.614        209        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.497      0.421      0.407      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      13.5G      1.465      1.767      1.602        251        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.467      0.416      0.403      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      13.2G      1.454      1.743      1.597        291        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.527      0.426      0.423      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      13.4G      1.457       1.72      1.581        260        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.6it/s 22.6s
#                    all       2340      10428      0.456      0.448       0.41      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      13.5G      1.437      1.692      1.573        289        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.542      0.454      0.462      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      13.4G      1.413      1.684      1.557        322        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428       0.58      0.405      0.428      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      13.5G      1.411      1.636      1.551        248        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.533      0.418      0.428      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      13.4G      1.403      1.622       1.55        235        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.572      0.414      0.443      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      13.5G      1.376       1.58      1.528        235        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.548      0.423      0.449      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      13.5G      1.382      1.568      1.523        217        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.514       0.47      0.466      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      13.6G      1.364      1.519      1.503        274        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.536      0.462      0.468      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      13.5G       1.37      1.542      1.513        293        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.552      0.474      0.485      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      13.4G      1.355       1.52      1.512        227        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.554      0.479      0.485      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      13.4G      1.342       1.49      1.501        293        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.572      0.482      0.492      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      13.5G      1.327      1.462      1.486        240        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.529      0.481      0.476      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      13.6G      1.316       1.43      1.482        285        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.567      0.482      0.488      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      13.4G      1.314       1.43      1.473        232        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.587      0.469       0.49      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      13.5G      1.306       1.43      1.464        228        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.565      0.492      0.499      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      13.5G      1.293       1.39      1.457        268        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.558      0.486      0.495      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      13.5G      1.297       1.38      1.448        248        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.561        0.5      0.504      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      13.5G      1.278      1.368      1.446        191        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.566      0.471      0.478      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      13.5G      1.269      1.337      1.434        215        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.608      0.485      0.516      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      13.5G       1.27      1.333      1.436        200        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.606      0.485       0.51      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      13.4G      1.259      1.315       1.43        283        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.567      0.491      0.512      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      13.4G      1.242      1.296      1.414        189        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.585      0.492      0.507      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      13.5G      1.241      1.287      1.416        220        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.615      0.495      0.527       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      13.5G      1.256       1.31      1.425        237        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428       0.62      0.488      0.521      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      13.4G      1.222      1.244      1.394        222        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.616      0.511      0.536      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      13.6G      1.216      1.231      1.392        238        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428       0.61      0.483      0.506       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      13.5G      1.214      1.222      1.383        320        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.599      0.519      0.531      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      13.5G      1.211      1.217      1.383        279        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.3s
#                    all       2340      10428      0.599      0.518      0.534      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      13.5G      1.204      1.203      1.384        216        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.1s
#                    all       2340      10428      0.604      0.507      0.529       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      13.6G      1.198      1.196      1.378        172        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.618      0.512      0.535      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      13.5G      1.199      1.181      1.366        313        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.622      0.509      0.537      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      13.4G      1.178      1.166      1.369        145        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.612      0.509      0.533      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      13.5G      1.156       1.13      1.351        314        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.645      0.508      0.539      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      13.4G      1.165       1.13       1.35        197        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.607      0.517      0.535      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      13.5G      1.154      1.106      1.341        225        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.2s
#                    all       2340      10428      0.629      0.525      0.554      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      13.5G      1.149      1.109      1.341        244        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.611      0.526      0.543      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      13.4G      1.137       1.09      1.334        238        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.657      0.513      0.552      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      12.9G      1.144      1.087      1.331        237        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.607       0.53      0.549       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      13.5G       1.14       1.09      1.331        281        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428       0.64      0.516      0.541      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      13.4G      1.134      1.077      1.322        254        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.638      0.525      0.544      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      13.5G      1.119      1.049      1.307        258        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 22.0s
#                    all       2340      10428      0.634      0.533      0.558      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      13.4G      1.105      1.036       1.31        264        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.629      0.534      0.556      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      13.4G      1.112      1.032      1.313        279        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428      0.621       0.53      0.547      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      13.4G      1.103      1.015      1.301        280        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.9s
#                    all       2340      10428       0.63      0.506      0.534       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      13.4G      1.099      1.016      1.298        219        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.7s
#                    all       2340      10428      0.636      0.512      0.538      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      13.4G      1.085     0.9922      1.294        232        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.611      0.536      0.545      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      13.4G      1.081     0.9952      1.286        248        832: 100% ━━━━━━━━━━━━ 94/94 1.1it/s 1:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.8s
#                    all       2340      10428      0.609      0.534      0.543       0.35
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 50, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 60 epochs completed in 1.821 hours.
# Optimizer stripped from /kaggle/working/runs/detect/batch_size/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/batch_size/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/batch_size/run_1/weights/best.pt...
# Ultralytics 8.4.33 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.5it/s 24.0s
#                    all       2340      10428      0.656      0.514      0.552      0.356
#                 person        989       3681      0.768      0.603      0.692      0.434
#                  table        678        970       0.69      0.547      0.618      0.413
#           potted plant        460       1204      0.693       0.64       0.67      0.353
#                  chair        531       1363      0.676      0.437      0.495      0.326
#                   sofa        449        596      0.712      0.704      0.732      0.529
#                   lamp        253        441      0.662      0.517      0.531      0.319
#                   door        171        249      0.582      0.237      0.315      0.187
#                cabinet        104        797      0.598      0.242      0.302      0.158
#               wardrobe         91        102      0.443      0.529      0.437      0.314
#           refrigerator        539        683      0.628      0.507      0.527      0.353
#                    bed        290        342      0.768      0.689      0.749      0.528
# Speed: 0.2ms preprocess, 6.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/batch_size/run_1

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  batch  imgsz     map50  map50_95  precision    recall
# 0    1     32    832  0.551735  0.355906   0.656394  0.513816

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

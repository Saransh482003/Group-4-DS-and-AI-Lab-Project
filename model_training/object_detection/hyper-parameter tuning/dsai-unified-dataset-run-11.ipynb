# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.2 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 138.1MB/s 0.1s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="lr_warmup",
)

# %%
param_grid = [
    {"lr0": 0.01,  "lrf": 0.01, "warmup_epochs": 3},
    {"lr0": 0.005, "lrf": 0.01, "warmup_epochs": 3},
    {"lr0": 0.003, "lrf": 0.01, "warmup_epochs": 5},
    {"lr0": 0.001, "lrf": 0.01, "warmup_epochs": 5},
    {"lr0": 0.001, "lrf": 0.001, "warmup_epochs": 5},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=lr_warmup, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/lr_warmup/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 68.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.6±0.3 ms, read: 28.1±10.1 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 249.7it/s 12.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 22.9±7.4 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 249.6it/s 9.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/lr_warmup/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/lr_warmup/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.89G      1.531      2.572      1.518        297        640: 100% ━━━━━━━━━━━━ 94/94 1.5it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.2s/it 43.2s
#                    all       2340      10428      0.435      0.345      0.323      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.81G      1.557      1.927      1.562        199        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 47.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.389      0.347      0.303      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.67G       1.61      1.995      1.609        287        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 47.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.276      0.244      0.195     0.0847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.651      2.082      1.661        258        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 47.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.392      0.293      0.277      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.97G       1.62      2.017      1.617        367        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428      0.341      0.347      0.279      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.98G      1.619      2.001      1.635        215        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428       0.62      0.281      0.306      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.87G      1.577      1.926      1.602        205        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.436       0.38      0.353      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.86G      1.539      1.873      1.578        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.464      0.381      0.369      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.72G      1.522      1.834      1.573        308        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.523      0.357      0.369      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80       7.8G      1.522      1.831      1.561        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.439      0.382      0.359      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.79G      1.507      1.788      1.554        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428       0.45      0.413      0.389      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.76G      1.483      1.748      1.536        251        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.478      0.416      0.403      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.67G      1.468      1.751      1.536        291        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.513      0.412      0.424      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.72G      1.477      1.717      1.526        260        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.532      0.404      0.419      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80       7.8G      1.457        1.7      1.515        289        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428       0.47      0.407      0.395      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.36G      1.447      1.681      1.502        322        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.531      0.405      0.413      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.72G      1.438       1.64      1.497        247        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.597      0.381      0.418      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.67G      1.437      1.635      1.501        234        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.545      0.431      0.442      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.98G      1.405      1.595      1.477        236        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.528      0.454      0.455      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      8.07G      1.413      1.579       1.47        217        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.542      0.425      0.441      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.67G      1.388       1.54      1.458        274        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.536      0.451      0.464      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80       7.8G      1.403      1.563      1.466        293        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.532      0.413      0.431      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.75G      1.384      1.542      1.466        227        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.545      0.467      0.465      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80       7.7G      1.375      1.512      1.455        293        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.582      0.472      0.486      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80       7.8G      1.357      1.484      1.436        239        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428       0.54      0.444      0.454      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.65G      1.349      1.446      1.433        284        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.545      0.454      0.453      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.76G      1.347      1.465      1.439        232        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.552      0.455      0.472      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.79G       1.33      1.448      1.423        228        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.576      0.483      0.509      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80       7.6G      1.323      1.415      1.412        268        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428       0.57      0.456      0.474      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.79G      1.333      1.412      1.412        247        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.571      0.486      0.501      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      7.78G      1.313      1.393        1.4        192        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.567      0.462      0.472      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.81G      1.311      1.379      1.403        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.555      0.483       0.49      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      7.81G      1.303      1.365      1.394        200        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.573      0.479      0.495      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.75G      1.291      1.337      1.385        283        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.564      0.482      0.497      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.74G      1.276      1.324      1.376        189        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.594      0.463      0.495      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      8.11G      1.275      1.313      1.379        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.592      0.466      0.497      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.67G      1.294      1.339      1.386        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428       0.56      0.471      0.481      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.66G      1.257      1.275       1.36        222        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.582      0.477      0.493      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.76G      1.249      1.259      1.354        238        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.634      0.449        0.5      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.73G      1.257      1.256      1.354        319        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.589      0.494      0.514      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.82G      1.248      1.256       1.35        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.598      0.457      0.484      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.81G      1.237      1.232      1.345        216        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.618      0.484      0.519      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.74G      1.233      1.228      1.343        172        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.582      0.511      0.525      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.79G       1.24      1.209      1.333        312        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.612      0.503      0.524      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.68G      1.216      1.203      1.333        145        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.641      0.473      0.513      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.79G      1.196      1.175      1.319        314        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.614      0.483      0.515      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80         8G      1.201       1.17      1.318        197        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.613      0.498      0.521      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.68G      1.196      1.141      1.313        225        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.617      0.492      0.522      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.78G      1.189      1.137      1.312        244        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.617      0.497      0.519      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.77G      1.175       1.12      1.296        238        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.609      0.494      0.519      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.73G      1.184      1.128        1.3        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.609      0.521       0.54      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.81G      1.187      1.132      1.305        281        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.659      0.455      0.511      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.68G       1.18       1.13      1.298        253        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.639      0.482      0.518      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.77G      1.166      1.091      1.286        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.633      0.509      0.538      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.75G      1.146      1.078       1.28        264        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.621      0.521      0.543      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80       8.1G       1.15      1.072       1.28        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.643      0.482      0.525      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.75G      1.143      1.049      1.268        279        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.624        0.5      0.528      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.73G      1.142      1.054      1.271        219        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.607      0.511      0.537      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.76G      1.129      1.034      1.267        231        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.618      0.521      0.537      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.75G      1.126      1.032      1.258        248        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.626      0.509      0.533      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.74G      1.113      1.024       1.25        286        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.617      0.515      0.542      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.12G      1.119       1.03      1.256        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.634      0.503      0.537      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.78G      1.107     0.9972      1.249        229        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.631      0.507      0.537      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.75G       1.11       1.01      1.248        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.622      0.514      0.539      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.82G      1.112      1.006      1.248        290        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.617      0.515      0.536      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.71G      1.089     0.9798      1.236        237        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428       0.63      0.504      0.531      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.74G      1.072     0.9598      1.225        220        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.633      0.498      0.534      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.72G      1.086     0.9782      1.236        171        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.648      0.496      0.536      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.76G      1.092     0.9766      1.239        302        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.632      0.504      0.535      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.73G      1.088     0.9811      1.237        382        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.628        0.5      0.533      0.345
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.73G     0.9342     0.7138      1.113        114        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.609      0.501      0.514      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      7.79G     0.8974     0.6292      1.091         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.616        0.5      0.523      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.76G     0.8981     0.6169      1.092        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428       0.64      0.496      0.526      0.337
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 63, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 73 epochs completed in 1.337 hours.
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/lr_warmup/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.4s
#                    all       2340      10428      0.631      0.508      0.537      0.347
#                 person        989       3681      0.731      0.615      0.679       0.43
#                  table        678        970      0.683      0.516      0.579       0.39
#           potted plant        460       1204      0.604      0.674       0.63      0.327
#                  chair        531       1363      0.627      0.458      0.488      0.319
#                   sofa        449        596      0.688      0.678      0.732      0.535
#                   lamp        253        441      0.601      0.503      0.503      0.295
#                   door        171        249      0.543      0.297      0.352      0.206
#                cabinet        104        797      0.803      0.189      0.347      0.177
#               wardrobe         91        102      0.372      0.373       0.32      0.223
#           refrigerator        539        683      0.628      0.523      0.528      0.365
#                    bed        290        342      0.663      0.759      0.754      0.552
# Speed: 0.1ms preprocess, 3.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/lr_warmup/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=lr_warmup, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/lr_warmup/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.9 ms, read: 174.4±89.6 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 698.0it/s 4.3s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 103.4±48.7 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 439.8it/s 5.3s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/lr_warmup/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/lr_warmup/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.94G      1.531      2.572      1.518        297        640: 100% ━━━━━━━━━━━━ 94/94 1.8it/s 53.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.435      0.345      0.323      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.82G      1.557      1.927      1.562        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.389      0.347      0.303      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80       7.8G       1.61      1.995      1.609        287        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.276      0.244      0.195     0.0847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.651      2.082      1.661        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.9s
#                    all       2340      10428      0.392      0.293      0.277      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.71G       1.62      2.017      1.617        367        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.341      0.347      0.279      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80         8G      1.619      2.001      1.635        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.4s
#                    all       2340      10428       0.62      0.281      0.306      0.158
#
# ...
#                    all       2340      10428      0.486      0.356      0.344      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80       7.8G       1.53      1.847      1.581        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.465      0.342      0.353      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      8.04G       1.52      1.802       1.57        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428       0.56      0.376      0.385      0.221
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 11 epochs completed in 0.203 hours.
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_4/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_4/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/lr_warmup/run_4/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.1s
#                    all       2340      10428      0.504      0.405      0.411      0.243
#                 person        989       3681      0.606      0.742      0.724      0.415
#                  table        678        970      0.574      0.542      0.544      0.331
#           potted plant        460       1204      0.537      0.614      0.565       0.26
#                  chair        531       1363       0.64      0.414      0.492      0.289
#                   sofa        449        596      0.567       0.73      0.708      0.461
#                   lamp        253        441      0.314       0.42       0.24      0.147
#                   door        171        249      0.319      0.012     0.0567     0.0252
#                cabinet        104        797      0.555     0.0094     0.0786     0.0328
#               wardrobe         91        102      0.184      0.049      0.059     0.0363
#           refrigerator        539        683      0.577      0.211      0.328      0.185
#                    bed        290        342      0.672      0.711      0.721      0.488
# Speed: 0.1ms preprocess, 3.4ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/lr_warmup/run_4
#
#
# ========== RUN 5 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.001, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=lr_warmup, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/lr_warmup/run_5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.8±0.8 ms, read: 201.4±62.1 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 755.8it/s 4.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 120.5±65.5 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 460.3it/s 5.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/lr_warmup/run_5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/lr_warmup/run_5
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.94G       1.52      2.689      1.507        297        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.502      0.406      0.411      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.81G      1.482        1.8      1.489        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.6s
#                    all       2340      10428      0.367      0.356      0.288      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.66G      1.558      1.893      1.551        287        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 16.5s
#                    all       2340      10428      0.382      0.379      0.326      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.554      1.879      1.567        258        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.379      0.307      0.285      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.98G      1.573       1.93      1.581        367        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.302      0.289      0.222      0.109
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.73G      1.617      2.007       1.63        215        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.404       0.26       0.24      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.88G      1.583      1.969      1.608        205        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.506      0.317      0.298       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.69G      1.549      1.902      1.582        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.1s
#                    all       2340      10428      0.463      0.365      0.337      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.98G      1.531      1.862      1.578        308        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.468      0.353       0.35      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      8.05G      1.533       1.85      1.565        249        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.457      0.386      0.368      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      8.04G      1.517      1.799       1.56        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.2s
#                    all       2340      10428      0.466      0.406      0.389       0.22
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 11 epochs completed in 0.204 hours.
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/lr_warmup/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/lr_warmup/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.6s
#                    all       2340      10428      0.504      0.405      0.411      0.243
#                 person        989       3681      0.606      0.742      0.724      0.415
#                  table        678        970      0.574      0.542      0.544      0.331
#           potted plant        460       1204      0.537      0.614      0.565       0.26
#                  chair        531       1363       0.64      0.414      0.492      0.289
#                   sofa        449        596      0.567       0.73      0.708      0.461
#                   lamp        253        441      0.314       0.42       0.24      0.147
#                   door        171        249      0.319      0.012     0.0567     0.0252
#                cabinet        104        797      0.555     0.0094     0.0786     0.0328
#               wardrobe         91        102      0.184      0.049      0.059     0.0363
#           refrigerator        539        683      0.577      0.211      0.328      0.185
#                    bed        290        342      0.672      0.711      0.721      0.488
# Speed: 0.1ms preprocess, 3.6ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/lr_warmup/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run    lr0    lrf  warmup_epochs     map50  map50_95  precision    recall
# 0    1  0.010  0.010              3  0.537338  0.347108   0.631319  0.507647
# 1    2  0.005  0.010              3  0.537338  0.347108   0.631319  0.507647
# 2    3  0.003  0.010              5  0.410590  0.242900   0.504027  0.404864
# 3    4  0.001  0.010              5  0.410590  0.242900   0.504027  0.404864
# 4    5  0.001  0.001              5  0.410590  0.242900   0.504027  0.404864

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.9 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 36.1MB/s 0.5s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="mosaic_mixup",
)

# %%
param_grid = [
    {"mosaic": 0.5, "mixup": 0.0},
    {"mosaic": 1.0, "mixup": 0.0},
    {"mosaic": 1.0, "mixup": 0.2},
    {"mosaic": 1.0, "mixup": 0.3},
    {"mosaic": 0.5, "mixup": 0.2},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=mosaic_mixup, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/mosaic_mixup/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 4.7MB/s 0.2s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 22.4MB/s 0.2s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 2.0±0.8 ms, read: 33.9±9.0 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 335.5it/s 8.9s
# WARNING ⚠️ train: Cache directory /kaggle/input/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 32.0±9.6 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 345.0it/s 6.8s
# WARNING ⚠️ val: Cache directory /kaggle/input/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/mosaic_mixup/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/mosaic_mixup/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.92G      1.419      2.673      1.422        157        640: 100% ━━━━━━━━━━━━ 94/94 1.5it/s 1:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.2s/it 42.8s
#                    all       2340      10428       0.44      0.334      0.302      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.64G       1.51      1.886      1.509        156        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.554      0.297      0.292      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.49G      1.538      1.889      1.542        183        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.326      0.246      0.182     0.0791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.48G      1.634      2.046      1.615        153        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.0s
#                    all       2340      10428      0.303       0.31      0.219     0.0981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.82G      1.582      1.985       1.59        163        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 16.3s
#                    all       2340      10428      0.279      0.266      0.216      0.102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.49G      1.556      1.909      1.578        136        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.401       0.32      0.317      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.56G       1.53      1.865      1.558        152        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.393      0.336      0.316      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.66G      1.498       1.78       1.53        192        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.9s
#                    all       2340      10428      0.427      0.348      0.323      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.71G      1.486      1.721       1.51        139        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.405      0.356      0.331      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.67G      1.471       1.71      1.506        209        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.406      0.388      0.348      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.56G      1.431      1.647      1.472        121        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428        0.5      0.394      0.386       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.62G      1.418      1.615       1.47        107        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.476      0.368      0.353      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.73G      1.415      1.602      1.466        191        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.447      0.396       0.38      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80       7.7G      1.401      1.564      1.457        156        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.7s
#                    all       2340      10428      0.516      0.412      0.402      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.49G      1.379      1.531      1.448        201        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.551      0.405      0.419      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      7.65G      1.368      1.499      1.427        194        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.493      0.426      0.416      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.66G      1.361      1.481      1.416        128        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.492      0.401        0.4      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      7.68G      1.333      1.437      1.406        160        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428       0.49      0.425      0.414       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.59G      1.333      1.445      1.405        208        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.532      0.427      0.441      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80       7.7G      1.309      1.391      1.393        168        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.513      0.422       0.43      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.51G       1.32      1.384      1.394        165        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.527       0.46      0.442      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      7.62G      1.308      1.367      1.381        192        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.603      0.392      0.434      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.71G      1.287       1.32      1.365        170        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.542      0.456      0.464      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      7.56G      1.279      1.305      1.352        129        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.553      0.459      0.468      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      7.67G      1.268      1.301      1.353        130        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.541      0.456      0.467       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.55G      1.256      1.265      1.343        172        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.554      0.447      0.462      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.54G       1.24      1.241      1.331        133        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.576      0.442      0.464      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.54G      1.236      1.221      1.329        128        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.558      0.452      0.467      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      7.75G      1.229      1.211      1.322        162        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.568      0.454      0.476      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.77G      1.221      1.187      1.323        124        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428       0.58      0.451      0.472       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      8.04G      1.208      1.158      1.311        161        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.569      0.472      0.486      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.67G      1.204      1.165      1.299        169        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.596      0.464      0.491        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      7.78G      1.205      1.144      1.301        141        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.602      0.463       0.49      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      8.04G      1.187      1.108      1.288        170        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.593      0.477      0.502      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.57G      1.183      1.106      1.286        118        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.583      0.486      0.508      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      7.73G      1.163      1.079      1.271        146        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.613      0.467      0.501      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.78G      1.167      1.067       1.27        173        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.601       0.49      0.504      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.77G      1.138      1.038      1.254        142        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.606      0.462      0.491      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.74G      1.144      1.032      1.262        191        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.585      0.495      0.508      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      7.77G      1.132      1.019      1.252        194        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.593      0.482      0.514      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.73G      1.115      0.984      1.239        219        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.615      0.482      0.501      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      7.63G       1.11     0.9761      1.235        135        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.612       0.46      0.496      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.51G      1.106     0.9543      1.225        173        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.631      0.468      0.507      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.73G      1.095     0.9491      1.222        141        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.632      0.447       0.49      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      7.73G      1.085     0.9326      1.218        110        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.613      0.486      0.505      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.76G      1.079      0.921      1.211        254        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.601      0.493      0.516      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.73G      1.074     0.9067      1.202        150        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.614      0.482      0.516      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.78G      1.062     0.8821      1.198        143        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.595       0.48      0.501       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.74G      1.063     0.8778      1.196        128        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.611      0.476      0.506      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.79G      1.046     0.8719      1.187        195        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428       0.63      0.487      0.518      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.77G      1.034     0.8484      1.179        172        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.645      0.463      0.503      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.79G      1.025     0.8281      1.169        194        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.616      0.488      0.519      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.77G       1.02     0.8256      1.166        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.613      0.485      0.505      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.78G      1.014     0.8216      1.173        153        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428       0.63      0.487      0.518       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80       7.7G      1.008     0.8009      1.164        199        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.626       0.49       0.52      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      7.76G     0.9965     0.7884      1.156        125        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.638      0.488      0.513      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.74G     0.9973     0.7849      1.153        195        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.3it/s 15.8s
#                    all       2340      10428      0.621      0.492      0.514       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.83G     0.9887     0.7741      1.145        191        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.631       0.48      0.516      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.64G     0.9758     0.7635      1.143        139        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.623      0.491      0.516      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.74G     0.9677     0.7501      1.134        133        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.631      0.486      0.511      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.76G       0.96     0.7402      1.134        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.611      0.491      0.512      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      7.79G     0.9672     0.7462      1.136        144        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.5it/s 15.0s
#                    all       2340      10428      0.629      0.493      0.523      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.78G     0.9485     0.7301      1.123        192        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.615      0.491      0.514      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.78G      0.952     0.7321      1.125        160        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428       0.66      0.478      0.521      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.57G     0.9395     0.7126      1.121        197        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.645      0.495       0.53      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.68G     0.9366     0.7057      1.116        206        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.628      0.493      0.519      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.72G     0.9316     0.7017      1.119        195        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.645       0.49      0.525       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.54G     0.9333     0.6987      1.107        142        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.5it/s 15.1s
#                    all       2340      10428      0.671      0.478      0.526      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.77G      0.926     0.6982      1.111        168        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.1s
#                    all       2340      10428      0.628      0.487      0.521      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.74G     0.9276     0.6875      1.108        169        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.1s
#                    all       2340      10428      0.682      0.476      0.528       0.34
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.55G     0.8569     0.5608      1.062        114        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.661      0.473      0.521      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80       7.5G     0.8501     0.5524      1.057         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.663      0.469      0.516      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.75G     0.8518     0.5531       1.06        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.649       0.48      0.519      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      7.73G     0.8464     0.5479      1.058        134        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.624      0.492       0.52      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      7.76G      0.842     0.5379      1.055        118        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.641      0.481      0.519      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      7.78G     0.8411      0.541      1.052         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428       0.66      0.474      0.521      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      7.78G     0.8384     0.5354      1.054         98        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.647       0.48       0.52      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      7.77G     0.8389     0.5387      1.055         85        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.1s
#                    all       2340      10428       0.65      0.478      0.519      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      7.79G     0.8372      0.539      1.048         87        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.5it/s 15.0s
#                    all       2340      10428      0.644      0.482       0.52      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      7.77G     0.8363      0.539      1.053         95        640: 100% ━━━━━━━━━━━━ 94/94 2.0it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.1s
#                    all       2340      10428      0.647      0.484       0.52      0.334
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 70, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 80 epochs completed in 1.457 hours.
# Optimizer stripped from /kaggle/working/runs/detect/mosaic_mixup/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/mosaic_mixup/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/mosaic_mixup/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.682      0.476      0.527       0.34
#                 person        989       3681      0.764      0.582      0.666      0.418
#                  table        678        970      0.724       0.52      0.589      0.394
#           potted plant        460       1204      0.699      0.606      0.627       0.32
#                  chair        531       1363      0.689      0.408      0.471      0.305
#                   sofa        449        596      0.746      0.691      0.728      0.523
#                   lamp        253        441       0.66      0.476      0.499      0.294
#                   door        171        249      0.532      0.257      0.313      0.197
#                cabinet        104        797      0.793      0.206      0.334      0.182
#               wardrobe         91        102      0.491      0.333      0.312       0.23
#           refrigerator        539        683      0.672      0.485      0.524      0.355
#                    bed        290        342      0.727      0.667       0.73       0.52
# Speed: 0.1ms preprocess, 3.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/mosaic_mixup/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=mosaic_mixup, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/mosaic_mixup/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.6±0.5 ms, read: 187.2±112.7 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 748.4it/s 4.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 119.1±70.6 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 481.4it/s 4.9s
# WARNING ⚠️ val: Cache directory /kaggle/input/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      7.74G       1.22      1.174      1.332        241        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.607      0.496      0.514      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      8.06G      1.213      1.151      1.325        193        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.7s
#                    all       2340      10428      0.604        0.5      0.514      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.82G       1.22      1.154      1.327        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.611      0.502      0.519      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.65G      1.208      1.146      1.323        186        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.634      0.473      0.512      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.86G      1.189      1.115      1.308        221        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.615      0.496      0.526      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.82G      1.183      1.124      1.308        152        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.661      0.489      0.535      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.74G       1.18      1.099        1.3        198        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.625      0.505      0.545      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.73G      1.182      1.104        1.3        191        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.651      0.494      0.526      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.64G      1.171      1.086      1.294        162        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.628      0.514      0.545       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80       7.8G      1.168      1.075      1.293        202        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.646      0.493      0.538      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      7.77G      1.147      1.039      1.281        189        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.638      0.511      0.549      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.83G      1.144      1.037      1.269        231        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.652      0.492       0.54      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.75G      1.141      1.034      1.275        187        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.627      0.515       0.54      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.77G      1.144      1.035      1.277        205        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.639      0.512      0.547      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.76G       1.13      1.007      1.266        179        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.651      0.493      0.535      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.77G      1.125      1.011      1.265        236        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.649      0.495      0.538      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      7.74G      1.119     0.9945      1.257        147        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.639        0.5      0.538      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.65G      1.123     0.9918      1.254        226        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.642      0.505      0.545      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.72G      1.101     0.9717      1.248        182        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.658      0.493      0.539      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.77G      1.107     0.9731      1.248        228        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.639      0.501      0.536      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80       7.8G      1.116     0.9826      1.254        207        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.638      0.495      0.533      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      7.97G      1.085     0.9564      1.246        228        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.632      0.509      0.543      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80         8G      1.093      0.971      1.244        256        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.645      0.511      0.544      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.73G      1.076      0.938      1.227        151        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.648      0.506      0.544      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.74G      1.096     0.9501      1.241        169        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428      0.649      0.497      0.541      0.352
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.47G     0.9052     0.6437      1.099        114        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 50.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.6s
#                    all       2340      10428       0.63      0.504      0.533      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      7.79G     0.8946     0.6162      1.092         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.641      0.498      0.532      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.76G     0.8986     0.6137      1.096        117        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.5s
#                    all       2340      10428      0.631      0.501      0.532      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      7.73G     0.8927     0.6054      1.093        134        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.2s
#                    all       2340      10428      0.641        0.5      0.535      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      7.63G     0.8829     0.5979      1.089        118        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.4s
#                    all       2340      10428      0.649      0.496      0.536      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      7.78G     0.8868     0.6012      1.088         86        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.644      0.502      0.535      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      7.78G     0.8858     0.5975      1.088         98        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.638      0.498      0.532      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      7.49G     0.8791     0.5981      1.086         85        640: 100% ━━━━━━━━━━━━ 94/94 1.9it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.4it/s 15.3s
#                    all       2340      10428      0.644      0.497      0.533      0.346
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 68, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 78 epochs completed in 1.430 hours.
# Optimizer stripped from /kaggle/working/runs/detect/mosaic_mixup/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/mosaic_mixup/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/mosaic_mixup/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.645       0.51      0.543      0.352
#                 person        989       3681      0.705      0.631      0.675      0.426
#                  table        678        970       0.69      0.569      0.613      0.416
#           potted plant        460       1204      0.668      0.637      0.638      0.335
#                  chair        531       1363      0.625      0.454      0.483      0.314
#                   sofa        449        596      0.768      0.679      0.743       0.54
#                   lamp        253        441      0.587       0.52      0.494      0.309
#                   door        171        249      0.514      0.318      0.351      0.207
#                cabinet        104        797      0.732      0.231      0.345      0.181
#               wardrobe         91        102      0.506      0.343       0.34      0.232
#           refrigerator        539        683      0.629      0.504      0.542      0.376
#                    bed        290        342      0.667      0.726      0.751      0.539
# Speed: 0.1ms preprocess, 3.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/mosaic_mixup/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  mosaic  mixup     map50  map50_95  precision    recall
# 0    1     0.5    0.0  0.526722  0.339761   0.681556  0.475572
# 1    2     1.0    0.0  0.545958  0.346450   0.635233  0.516659
# 2    3     1.0    0.2  0.537338  0.347108   0.631319  0.507647
# 3    4     1.0    0.3  0.553103  0.352821   0.639897  0.523925
# 4    5     0.5    0.2  0.543208  0.352306   0.644623  0.510185

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()

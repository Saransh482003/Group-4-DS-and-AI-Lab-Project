# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s eta 0:00:00

# %%
import os
import random
import numpy as np
import torch
import pandas as pd
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os

if os.path.exists("/kaggle/input/dsai-unified-dataset"):
    DATA_PATH = "/kaggle/input/dsai-unified-dataset"
else:
    DATA_PATH = "/kaggle/input/datasets/ds22f1001123/dsai-unified-dataset"

print("Using dataset path:", DATA_PATH)
# Out:
# Using dataset path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# %%
train_images_path = os.path.join(DATA_PATH, 'images/train')
all_images = [os.path.join(train_images_path, f) for f in os.listdir(train_images_path) if f.endswith(('.jpg', '.png'))]
all_images.sort()

seed = 2306
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
subset_3000 = random.sample(all_images, 3000)

# %%
with open('/kaggle/working/subset_train.txt', 'w') as f:
    for img in subset_3000:
        f.write(f"{img}\n")

# %%
with open("data.yaml", "w") as f:
    f.write(f"""
path: {DATA_PATH}

train: /kaggle/working/subset_train.txt
val: images/val

names:
  0: person
  1: table
  2: potted plant
  3: chair
  4: sofa
  5: lamp
  6: door
  7: cabinet
  8: wardrobe
  9: refrigerator
  10: bed
""")

# %%
model = YOLO("yolo11s.pt")
DATA_YAML = "/kaggle/working/data.yaml"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 113.9MB/s 0.2s

# %%
# with open("YAML.yaml", "w") as f:
#     f.write("""
# path: /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset

# train: images/train
# val: images/val

# names:
#   0: person
#   1: table
#   2: potted plant
#   3: chair
#   4: sofa
#   5: lamp
#   6: door
#   7: cabinet
#   8: wardrobe
#   9: refrigerator
#   10: bed
#     """)

# %%
base_params = dict(
    data=DATA_YAML,
    epochs=80,
    patience=10,
    imgsz=640,
    batch=32,
    device=0,

    fliplr=0.5,
    degrees=10,
    translate=0.15,
    scale=0.5,
    mosaic=1.0,
    mixup=0.2,

    hsv_h=0.015,
    hsv_s=0.6,
    hsv_v=0.4,

    cos_lr=True,
    close_mosaic=10,
    warmup_epochs=3,

    seed=2306,
    deterministic=True,
    
    project="light_aug",
)

# %%
param_grid = [
    {"hsv_h": 0.01, "hsv_s": 0.5, "hsv_v": 0.3},
    {"hsv_h": 0.015, "hsv_s": 0.6, "hsv_v": 0.4},
    {"hsv_h": 0.02, "hsv_s": 0.7, "hsv_v": 0.5},
    {"hsv_h": 0.015, "hsv_s": 0.7, "hsv_v": 0.3},
    {"hsv_h": 0.02, "hsv_s": 0.5, "hsv_v": 0.5},
]

# %%
results = []

for i, params in enumerate(param_grid):
    print(f"\n\n========== RUN {i+1} ==========\n")

    model = YOLO("yolo11s.pt")
    
    train_params = base_params.copy()
    train_params.update(params)
    train_params["name"] = f"run_{i+1}"
    train_params["exist_ok"] = True
    
    metrics = model.train(**train_params)
    
    results.append({
        "run": i+1,
        **params,
        "map50": metrics.box.map50,
        "map50_95": metrics.box.map,
        "precision": metrics.box.mp,
        "recall": metrics.box.mr,
    })
# Out:
# ========== RUN 1 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.5, hsv_v=0.3, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=light_aug, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/light_aug/run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.5MB/s 0.0s
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 68.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.7±1.9 ms, read: 19.8±11.7 MB/s, size: 112.6 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 265.2it/s 11.3s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 24.4±7.6 MB/s, size: 118.0 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 242.1it/s 9.7s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/light_aug/run_1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/light_aug/run_1
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.89G      1.529       2.57      1.516        297        640: 100% ━━━━━━━━━━━━ 94/94 1.4it/s 1:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.3s/it 46.6s
#                    all       2340      10428      0.486      0.346      0.332      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.81G       1.55      1.905      1.551        199        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.443       0.34      0.328      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.67G       1.61      1.989      1.605        287        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.9s
#                    all       2340      10428      0.317      0.275       0.21     0.0907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.653      2.082      1.657        258        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428      0.377      0.318      0.301      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.97G      1.605          2      1.615        367        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.362      0.309      0.259      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.98G      1.601       1.99      1.626        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.9s
#                    all       2340      10428       0.56      0.284      0.299      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      7.87G      1.566      1.917      1.601        205        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.438      0.352       0.35      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.86G      1.531      1.863      1.574        186        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.503      0.387      0.374      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.72G      1.515      1.821      1.568        308        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.462      0.367      0.352      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80       7.8G      1.521      1.829      1.568        249        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.442      0.329      0.329      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      7.79G       1.51       1.78      1.558        209        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.527      0.379      0.394      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.76G      1.474      1.742      1.537        251        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.507      0.409      0.412      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.67G      1.473      1.759       1.55        291        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.476      0.428      0.411      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.72G      1.471      1.709      1.526        260        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.501      0.424      0.414      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80       7.8G      1.454      1.685      1.516        289        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.511      0.432      0.436      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.36G      1.441      1.661      1.506        322        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.524      0.433      0.433      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      7.73G      1.428      1.638      1.502        247        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.588      0.398      0.423       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      8.01G      1.425       1.61      1.497        234        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.536      0.408      0.413      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      7.79G      1.401      1.577      1.471        236        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428       0.52      0.457      0.459      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      7.78G      1.408      1.563      1.465        217        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.521      0.429      0.434      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      7.67G      1.385      1.523      1.453        274        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.564      0.464      0.473      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80       7.8G      1.396      1.548      1.462        293        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.514      0.445      0.445      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      7.75G      1.381      1.527      1.464        227        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.539       0.43      0.449      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80       7.7G      1.364      1.497      1.446        293        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428       0.55      0.482      0.481      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80       7.8G      1.357      1.478      1.437        239        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.521      0.455      0.451      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      7.65G      1.343      1.442       1.43        284        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.563      0.445      0.469      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      7.76G      1.345      1.462      1.435        232        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428       0.55       0.46      0.469      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      7.79G      1.328      1.427      1.418        228        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.548      0.482      0.487      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80       7.6G      1.317      1.399       1.41        268        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.555      0.443      0.457       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      7.79G      1.322      1.395      1.403        247        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.546      0.474      0.485        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      7.78G      1.313      1.391      1.403        192        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428       0.53      0.464      0.468      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      7.83G      1.303      1.368      1.394        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.535      0.463       0.47      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      8.08G      1.296      1.354      1.389        200        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.583       0.45      0.474      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      7.86G      1.283      1.323      1.378        283        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.614      0.473      0.515      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      7.85G      1.274      1.315      1.372        189        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.578      0.466      0.493      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80       8.1G      1.269        1.3      1.373        220        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.571      0.466      0.489      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      7.72G      1.283       1.32       1.38        237        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.603      0.486      0.507      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      7.75G      1.253      1.259       1.36        222        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428        0.6      0.476      0.502      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      7.66G      1.246      1.253      1.353        238        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.596        0.5      0.514      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80       7.8G      1.253       1.25      1.348        319        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.581      0.476      0.502      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      7.58G       1.24      1.241      1.342        279        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.0s
#                    all       2340      10428      0.594      0.484      0.502      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80       7.8G      1.233      1.222      1.345        216        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.594      0.491      0.508      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      7.74G      1.221      1.219      1.339        172        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.603      0.495      0.521      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      7.78G       1.23      1.202      1.333        312        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.611      0.516      0.535      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      8.02G      1.211        1.2      1.331        145        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.626      0.476      0.509      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      8.04G      1.189      1.163      1.317        314        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.619      0.504      0.543       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      7.78G      1.199      1.159      1.315        197        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.633      0.502      0.537       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.69G      1.191      1.128      1.307        225        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.641      0.502      0.539      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.77G      1.179      1.131      1.305        244        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.2s
#                    all       2340      10428      0.594      0.514      0.523      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.77G       1.17      1.119      1.296        238        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.621      0.481      0.515      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.73G       1.18      1.118      1.298        237        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.622      0.498      0.534      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      7.81G      1.182      1.123        1.3        281        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.629      0.489      0.528      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.68G      1.174      1.117      1.294        253        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.632      0.492      0.525      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.77G      1.157      1.081       1.28        258        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.649      0.499      0.543      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.75G      1.142      1.068      1.279        264        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.615       0.52      0.541      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80       8.1G      1.145      1.059      1.276        279        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.637      0.506      0.534       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.75G       1.14      1.042      1.267        279        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.631      0.494      0.526      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.73G      1.138      1.041      1.269        219        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.619      0.493      0.529      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.76G      1.121      1.031      1.265        231        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.631      0.506      0.538      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.75G      1.122      1.029      1.258        248        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.1s
#                    all       2340      10428      0.634      0.494      0.527      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.74G       1.11      1.015      1.249        286        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.632      0.512      0.541      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.04G      1.117      1.022      1.255        220        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.3s
#                    all       2340      10428      0.644      0.506      0.541      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.76G      1.099     0.9883      1.242        229        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.2it/s 17.2s
#                    all       2340      10428      0.654      0.489      0.533      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      7.88G      1.107     0.9988      1.246        249        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.4s
#                    all       2340      10428      0.645        0.5      0.543      0.347
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 54, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 64 epochs completed in 1.347 hours.
# Optimizer stripped from /kaggle/working/runs/detect/light_aug/run_1/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/light_aug/run_1/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/light_aug/run_1/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.9it/s 19.8s
#                    all       2340      10428      0.646        0.5      0.543      0.348
#                 person        989       3681      0.726      0.604      0.669       0.42
#                  table        678        970      0.675      0.566      0.612      0.412
#           potted plant        460       1204      0.657      0.642      0.647      0.342
#                  chair        531       1363       0.64      0.443      0.484      0.313
#                   sofa        449        596      0.731      0.636      0.721      0.521
#                   lamp        253        441      0.634      0.463      0.508      0.291
#                   door        171        249      0.535      0.357      0.389       0.24
#                cabinet        104        797       0.77      0.237      0.389      0.193
#               wardrobe         91        102      0.437      0.343      0.293      0.214
#           refrigerator        539        683       0.63      0.512      0.537      0.365
#                    bed        290        342      0.676      0.696       0.72      0.517
# Speed: 0.1ms preprocess, 4.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/light_aug/run_1
#
#
# ========== RUN 2 ==========
#
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.6, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=light_aug, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/light_aug/run_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=2306, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823665  ultralytics.nn.modules.head.Detect           [11, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,432,049 parameters, 9,432,033 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.8±0.5 ms, read: 205.3±68.3 MB/s, size: 111.7 KB)
# train: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/train... 3000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 736.6it/s 4.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 127.1±59.3 MB/s, size: 116.3 KB)
# val: Scanning /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels/val... 2340 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2340/2340 440.5it/s 5.3s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/ds22f1001123/dsai-unified-dataset/labels is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/light_aug/run_2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/light_aug/run_2
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      7.93G      1.531      2.572      1.518        297        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 59.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.435      0.345      0.323      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      7.82G      1.557      1.927      1.562        199        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.389      0.347      0.303      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      7.78G       1.61      1.995      1.609        287        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.276      0.244      0.195     0.0847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      7.75G      1.651      2.082      1.661        258        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.3s
#                    all       2340      10428      0.392      0.293      0.277      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      7.72G       1.62      2.017      1.617        367        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.5s
#                    all       2340      10428      0.341      0.347      0.279      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      7.79G      1.619      2.001      1.635        215        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428       0.62      0.281      0.306      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      8.13G      1.577      1.926      1.602        205        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.436       0.38      0.353      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      7.88G      1.539      1.873      1.578        186        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.464      0.381      0.369      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      7.72G      1.522      1.834      1.573        308        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.523      0.357      0.369      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      7.76G      1.522      1.831      1.561        249        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.439      0.382      0.359      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      8.02G      1.507      1.788      1.554        209        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428       0.45      0.413      0.389      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      7.75G      1.483      1.748      1.536        251        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428      0.478      0.416      0.403      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      7.68G      1.468      1.751      1.536        291        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.513      0.412      0.424      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      7.77G      1.477      1.717      1.526        260        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.532      0.404      0.419      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      7.81G      1.457        1.7      1.515        289        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.5s
#                    all       2340      10428       0.47      0.407      0.395      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      8.12G      1.447      1.681      1.502        322        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      7.83G      1.197      1.144      1.315        225        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.627      0.513      0.541      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      7.71G       1.19      1.149      1.315        244        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.633      0.504      0.536      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      7.77G       1.18      1.125      1.303        238        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428       0.64      0.487      0.524       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      7.72G      1.183      1.129      1.302        237        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.9s
#                    all       2340      10428       0.63      0.511      0.544      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80       7.8G      1.186      1.136      1.303        281        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.639      0.504      0.538      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      7.78G      1.183      1.133      1.303        253        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428      0.642       0.51      0.534      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      7.79G      1.169      1.098      1.287        258        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428      0.642      0.511      0.548      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      7.99G      1.147       1.08      1.284        264        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.661       0.51      0.554      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      8.04G      1.152      1.085      1.285        279        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428       0.62      0.515       0.54      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      7.74G      1.144      1.059      1.272        279        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428      0.613      0.513      0.533      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      7.73G      1.142      1.059      1.274        219        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428      0.638      0.515      0.547      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      7.77G      1.132      1.042      1.272        231        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.625      0.515      0.537      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      7.76G      1.133      1.043      1.267        248        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.6s
#                    all       2340      10428      0.634      0.523      0.549      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      7.74G      1.118      1.031      1.254        286        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428      0.626      0.531      0.548      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      8.12G      1.125      1.038      1.261        220        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.652      0.516       0.55      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      7.79G      1.107      1.001      1.251        229        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.638      0.525      0.547      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80         8G      1.114      1.014      1.253        249        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.657      0.511      0.547      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      7.82G      1.113      1.012      1.251        290        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428      0.632       0.52      0.544      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      7.72G      1.094     0.9872      1.241        237        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.639      0.511      0.547      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80         8G      1.075     0.9597      1.225        220        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.647      0.501       0.54      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      7.72G       1.09     0.9817      1.239        171        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428      0.636      0.522      0.548      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      7.76G      1.096     0.9814      1.244        302        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428      0.667      0.513      0.548      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      7.75G      1.095      0.988      1.244        382        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 57.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.7s
#                    all       2340      10428       0.65      0.517      0.552      0.355
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      7.56G     0.9374     0.7272      1.115        114        640: 100% ━━━━━━━━━━━━ 94/94 1.6it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.646      0.491      0.518      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      7.78G     0.9027     0.6364      1.096         86        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.9s
#                    all       2340      10428       0.63      0.505      0.527      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      7.76G     0.8953     0.6227      1.094        117        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.648      0.497      0.529      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      7.73G     0.8903     0.6129      1.093        134        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428      0.638      0.503      0.531      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      7.76G     0.8834     0.6028      1.086        118        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428       0.64      0.511      0.536      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      7.77G     0.8824     0.6042      1.084         86        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.9s
#                    all       2340      10428      0.659      0.496      0.532       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      7.78G     0.8837     0.5994      1.088         98        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 17.8s
#                    all       2340      10428      0.663      0.496      0.533       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      7.77G     0.8812     0.5972      1.087         85        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.1it/s 18.0s
#                    all       2340      10428      0.639      0.507      0.531      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      7.78G     0.8775     0.5947      1.078         87        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.1s
#                    all       2340      10428       0.65      0.499      0.531      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      7.78G     0.8817     0.5943      1.084         95        640: 100% ━━━━━━━━━━━━ 94/94 1.7it/s 56.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 2.0it/s 18.2s
#                    all       2340      10428       0.64      0.508      0.533      0.341
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 70, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 80 epochs completed in 1.690 hours.
# Optimizer stripped from /kaggle/working/runs/detect/light_aug/run_5/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/light_aug/run_5/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/light_aug/run_5/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,417,057 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 37/37 1.7it/s 21.2s
#                    all       2340      10428      0.648      0.518      0.552      0.355
#                 person        989       3681      0.716      0.633      0.681      0.434
#                  table        678        970       0.68      0.558      0.618      0.418
#           potted plant        460       1204      0.655      0.639      0.642      0.341
#                  chair        531       1363      0.619      0.473      0.494      0.321
#                   sofa        449        596      0.711       0.69      0.738      0.537
#                   lamp        253        441      0.608      0.501      0.514      0.302
#                   door        171        249      0.626      0.342      0.383      0.215
#                cabinet        104        797      0.765      0.255      0.363      0.184
#               wardrobe         91        102      0.425      0.363      0.366       0.26
#           refrigerator        539        683      0.609      0.527       0.54      0.358
#                    bed        290        342      0.715      0.722      0.738      0.537
# Speed: 0.1ms preprocess, 4.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/light_aug/run_5

# %%
df = pd.DataFrame(results)
df.to_csv("results_scale_tuning.csv", index=False)
print(df)
# Out:
#    run  hsv_h  hsv_s  hsv_v     map50  map50_95  precision    recall
# 0    1  0.010    0.5    0.3  0.542579  0.347957   0.646275  0.500075
# 1    2  0.015    0.6    0.4  0.537338  0.347108   0.631319  0.507647
# 2    3  0.020    0.7    0.5  0.543675  0.351020   0.612500  0.526673
# 3    4  0.015    0.7    0.3  0.541528  0.345791   0.622221  0.511421
# 4    5  0.020    0.5    0.5  0.552419  0.355174   0.648026  0.518363

# %%
# results = model.train(
#     data=DATA_YAML,
#     epochs=50,
#     imgsz=640,
#     batch=32,          # 🔥 important
#     device=0,

#     degrees=0,
#     translate=0,
#     scale=0,
#     fliplr=0,
#     hsv_h=0,
#     hsv_s=0,
#     hsv_v=0,

#     patience=10
# )

# %%
# val_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# metrics = val_model.val(data=DATA_YAML)

# print(f"mAP@50-95: {metrics.box.map:.4f}")
# print(f"mAP@50:    {metrics.box.map50:.4f}")
# print(f"Precision: {metrics.box.mp:.4f}")
# print(f"Recall:    {metrics.box.mr:.4f}")

# %%
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

# results_dir = '/kaggle/working/runs/detect/train/'

# plt.figure(figsize=(10, 10))
# img = mpimg.imread(os.path.join(results_dir, 'confusion_matrix.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Confusion Matrix')
# plt.show()

# plt.figure(figsize=(12, 8))
# img = mpimg.imread(os.path.join(results_dir, 'results.png'))
# plt.imshow(img)
# plt.axis('off')
# plt.title('Training Metrics and Loss Curves')
# plt.show()
